# %%
# Importa o pandas
from main import formata_txt
import pandas as pd
import datetime
import openpyxl

# Chama a função passando o nome do arquivo txt entre aspas, que será modificado

formata_txt("teste.txt")

# Lê o arquivo já modificado

df = pd.read_csv(

    # Nome do arquivo

    "teste.txt",

    # Usa o espaço entre as palavras para separar por colunas

    delim_whitespace=True,

    # Usa estes nomes como nomes das colunas (alterar a vontade)

    names=["Dept Sta", "Arvl Sta", "Dept Day", "Week-Day", "Pax-Subfleet", "Arvl-Hora", "Dept-Hora", "Svc Type", "FlightNumbeR", "FlightNumberArvl"],

    header=None,

)

# Imprime as linhas concactena e gera as duas Keys para filtro (Key e KeyX)
df['Concatenar'] = df['Arvl Sta'] + df['Dept Sta'] + df['Dept Day'] + df['Week-Day'] + df['Pax-Subfleet'] + df['Pax-Subfleet'] + df['Arvl-Hora'] + df['Dept-Hora'] + df['Svc Type']

df['Concatenar'] = df['Concatenar'].astype(str)
df['Key'] = df['Concatenar'].str.len()
df['KeyX'] = df['Svc Type'].astype(str)
df['KeyX'] = df['KeyX'].str.len()
df['Kdept'] = df['Dept-Hora'].astype(str)
df['Kdept'] = df['Kdept'].str.len()
df['Karvl'] = df['Arvl-Hora'].astype(str)
df['Karvl'] = df['Karvl'].str.len()
df_orig = df
df_orig
# Out:
#      Dept Sta Arvl Sta    Dept Day Week-Day Pax-Subfleet Arvl-Hora  \
# 0      H5X414    5X414  14MAR21MAR  0200000       00076F   MIA1950
# 1      H5X415    5X415       02NOV        -       00076F   EZE0915
# 2      H5X415    5X415  09NOV23NOV  0030000       00076F   EZE0925
# 3      H5X415    5X415  30NOV21DEC  0030000       00076F   EZE0935
# 4      H5X415    5X415       28DEC        -       00076F   EZE1125
# ...       ...      ...         ...      ...          ...       ...
# 6773  HWD9622        -       03NOV        -       000734   POA1440
# 6774  HWD9622        -       17NOV        -       000734   CNF1335
# 6775        H   WD9622       22NOV        -       000734         -
# 6776        H   WD9622       05DEC        -       000734         -
# 6777  HWD9622        -       08DEC        -       000734   CGR1515
#
#        Dept-Hora Svc Type  FlightNumbeR  FlightNumberArvl  \
# 0     2210SCLEZE       FF           NaN               NaN
# 1     1050BOGMIA       FF           NaN               NaN
# 2        1330MIA       FF           NaN               NaN
# 3        1330MIA       FF           NaN               NaN
# 4        1310MIA       FF           NaN               NaN
# ...          ...      ...           ...               ...
# 6773           -        P           NaN               NaN
# 6774           -        P           NaN               NaN
# 6775     0705GIG        P           NaN               NaN
# 6776     1330SJK        P           NaN               NaN
# 6777           -        P           NaN               NaN
#
#                                              Concatenar  Key  KeyX  Kdept  \
# 0     5X414H5X41414MAR21MAR020000000076F00076FMIA195...   59     2     10
# 1      5X415H5X41502NOV-00076F00076FEZE09151050BOGMIAFF   48     2     10
# 2     5X415H5X41509NOV23NOV003000000076F00076FEZE092...   56     2      7
# 3     5X415H5X41530NOV21DEC003000000076F00076FEZE093...   56     2      7
# 4         5X415H5X41528DEC-00076F00076FEZE11251310MIAFF   45     2      7
# ...                                                 ...  ...   ...    ...
# 6773                -HWD962203NOV-000734000734POA1440-P   35     1      1
# 6774                -HWD962217NOV-000734000734CNF1335-P   35     1      1
# 6775                 WD9622H22NOV-000734000734-0705GIGP   34     1      7
# 6776                 WD9622H05DEC-000734000734-1330SJKP   34     1      7
# 6777                -HWD962208DEC-000734000734CGR1515-P   35     1      1
#
#       Karvl
# 0         7
# 1         7
# 2         7
# 3         7
# 4         7
# ...     ...
# 6773      7
# 6774      7
# 6775      1
# 6776      1
# 6777      7
#
# [6778 rows x 15 columns]

# %%
df_frame45 = df_orig.query('KeyX == 1  & Key == 45 & Kdept == 7')
df_frame45['FlightNumbeR'] = df_frame45['Arvl Sta']
df_frame45['Dept Sta'] = 'VCP'
df_frame45['Arvl Sta'] = df_frame45['Dept-Hora'].apply( lambda x: x[4:7])
df_frame45['Arvl Day'] = df_frame45['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame45['Dept Day'] = df_frame45['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame45['Trilho'] = ''
df_frame45['Pax'] = df_frame45['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame45['Pax-Subfleet'] = df_frame45['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame45['Arvl-Hora'] = '00:00'
df_frame45['Dept-Hora'] = df_frame45['Dept-Hora'].apply(lambda x: x[0:2] + ':' + x[2:4])
df_frame45 = df_frame45[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
df_frame45
p1 = df_frame45
p1
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2374302361.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['FlightNumbeR'] = df_frame45['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2374302361.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Dept Sta'] = 'VCP'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2374302361.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Arvl Sta'] = df_frame45['Dept-Hora'].apply( lambda x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2374302361.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Arvl Day'] = df_frame45['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2374302361.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Dept Day'] = df_frame45['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2374302361.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2374302361.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Pax'] = df_frame45['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2374302361.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Pax-Subfleet'] = df_frame45['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2374302361.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Arvl-Hora'] = '00:00'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2374302361.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Dept-Hora'] = df_frame45['Dept-Hora'].apply(lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 47        VCP      MAO  30/OCT/2023 á 01/NOV/2023  30/OCT/2023 á 01/NOV/2023
# 50        VCP      MAO  03/NOV/2023 á 04/NOV/2023  03/NOV/2023 á 04/NOV/2023
# 51        VCP      MAO  05/NOV/2023 á 22/NOV/2023  05/NOV/2023 á 22/NOV/2023
# 52        VCP      MAO  07/NOV/2023 á 21/NOV/2023  07/NOV/2023 á 21/NOV/2023
# 55        VCP      MAO  17/NOV/2023 á 23/NOV/2023  17/NOV/2023 á 23/NOV/2023
# ...       ...      ...                        ...                        ...
# 6721      VCP      MAO  11/MAR/2023 á 25/MAR/2023  11/MAR/2023 á 25/MAR/2023
# 6728      VCP      REC  03/NOV/2023 á 08/NOV/2023  03/NOV/2023 á 08/NOV/2023
# 6736      VCP      REC  19/JAN/2023 á 02/MAR/2023  19/JAN/2023 á 02/MAR/2023
# 6737      VCP      REC  07/MAR/2023 á 25/MAR/2023  07/MAR/2023 á 25/MAR/2023
# 6756      VCP      GIG  09/NOV/2023 á 15/NOV/2023  09/NOV/2023 á 15/NOV/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR  FlightNumberArvl Trilho  \
# 47       06:45     00:00          73P       AD2002               NaN
# 50       05:20     00:00          73P       AD2002               NaN
# 51       07:00     00:00          73P       AD2002               NaN
# 52       08:00     00:00          73P       AD2002               NaN
# 55       07:00     00:00          73P       AD2002               NaN
# ...        ...       ...          ...          ...               ...    ...
# 6721     11:55     00:00          734       WD5802               NaN
# 6728     13:50     00:00          734       WD5806               NaN
# 6736     13:50     00:00          734       WD5806               NaN
# 6737     12:25     00:00          734       WD5806               NaN
# 6756     17:00     00:00          734       WD9620               NaN
#
#      Svc Type  Pax Week-Day
# 47          F  000  0200007
# 50          F  000  0004500
# 51          F  000  0200067
# 52          F  000  1030000
# 55          F  000  0034000
# ...       ...  ...      ...
# 6721        F  000  0000060
# 6728        F  000  0204000
# 6736        F  000  0204000
# 6737        F  000  0204060
# 6756        P  000  0230000
#
# [2152 rows x 13 columns]

# %%
df_frame34 = df_orig.query('KeyX == 1  & Key == 34 & Kdept == 7')
df_frame34['FlightNumbeR'] = df_frame34['Arvl Sta']
df_frame34['Dept Sta'] = 'VCP'
df_frame34['Arvl Sta'] = df_frame34['Dept-Hora'].apply( lambda x: x[4:7])
df_frame34['Arvl Day'] = df_frame34['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame34['Dept Day'] = df_frame34['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame34['Trilho'] = ''
df_frame34['Pax'] = df_frame34['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame34['Pax-Subfleet'] = df_frame34['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame34['Arvl-Hora'] = '00:00'
df_frame34['Dept-Hora'] = df_frame34['Dept-Hora'].apply(lambda x: x[0:2] + ':' + x[2:4])
df_frame34 = df_frame34[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p2 = df_frame34
p2
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2960174063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame34['FlightNumbeR'] = df_frame34['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2960174063.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame34['Dept Sta'] = 'VCP'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2960174063.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame34['Arvl Sta'] = df_frame34['Dept-Hora'].apply( lambda x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2960174063.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame34['Arvl Day'] = df_frame34['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2960174063.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame34['Dept Day'] = df_frame34['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2960174063.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame34['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2960174063.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame34['Pax'] = df_frame34['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2960174063.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame34['Pax-Subfleet'] = df_frame34['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2960174063.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame34['Arvl-Hora'] = '00:00'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2960174063.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame34['Dept-Hora'] = df_frame34['Dept-Hora'].apply(lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 48        VCP      MAO  31/OCT/2023  31/OCT/2023     08:30     00:00
# 49        VCP      MAO  02/NOV/2023  02/NOV/2023     07:20     00:00
# 53        VCP      MAO  10/NOV/2023  10/NOV/2023     07:30     00:00
# 54        VCP      MAO  11/NOV/2023  11/NOV/2023     07:55     00:00
# 59        VCP      MAO  30/NOV/2023  30/NOV/2023     07:55     00:00
# ...       ...      ...          ...          ...       ...       ...
# 6765      VCP      SJK  30/DEC/2023  30/DEC/2023     10:00     00:00
# 6766      VCP      GIG  04/JAN/2023  04/JAN/2023     07:00     00:00
# 6769      VCP      GIG  08/DEC/2023  08/DEC/2023     07:40     00:00
# 6775      VCP      GIG  22/NOV/2023  22/NOV/2023     07:05     00:00
# 6776      VCP      SJK  05/DEC/2023  05/DEC/2023     13:30     00:00
#
#      Pax-Subfleet FlightNumbeR  FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 48            73P       AD2002               NaN               F  000        -
# 49            73P       AD2002               NaN               F  000        -
# 53            73P       AD2002               NaN               F  000        -
# 54            73P       AD2002               NaN               F  000        -
# 59            73P       AD2002               NaN               F  000        -
# ...           ...          ...               ...    ...      ...  ...      ...
# 6765          734       WD9620               NaN               P  000        -
# 6766          734       WD9620               NaN               P  000        -
# 6769          733       WD9621               NaN               P  000        -
# 6775          734       WD9622               NaN               P  000        -
# 6776          734       WD9622               NaN               P  000        -
#
# [829 rows x 13 columns]

# %%
df_frame48 = df_orig.query('KeyX == 1  & Key == 48 & Kdept == 10')
df_frame48['FlightNumbeR'] = df_frame48['Arvl Sta']
df_frame48['Dept Sta'] = 'VCP'
df_frame48['Arvl Sta'] = df_frame48['Dept-Hora'].apply( lambda x: x[4:7])
df_frame48['Arvl Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame48['Dept Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame48['Trilho'] = ''
df_frame48['Pax'] = df_frame48['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame48['Pax-Subfleet'] = df_frame48['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame48['Arvl-Hora'] = '00:00'
df_frame48['Dept-Hora'] = df_frame48['Dept-Hora'].apply(lambda x: x[0:2] + ':' + x[2:4])
df_frame48 = df_frame48[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p3 = df_frame48
p3
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2686295451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['FlightNumbeR'] = df_frame48['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2686295451.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept Sta'] = 'VCP'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2686295451.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl Sta'] = df_frame48['Dept-Hora'].apply( lambda x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2686295451.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2686295451.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2686295451.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2686295451.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Pax'] = df_frame48['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2686295451.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Pax-Subfleet'] = df_frame48['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2686295451.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl-Hora'] = '00:00'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2686295451.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept-Hora'] = df_frame48['Dept-Hora'].apply(lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 117       VCP      BEL  31/OCT/2023 á 09/NOV/2023  31/OCT/2023 á 09/NOV/2023
# 118       VCP      BEL  12/NOV/2023 á 31/DEC/2023  12/NOV/2023 á 31/DEC/2023
# 119       VCP      BEL  01/DEC/2023 á 09/DEC/2023  01/DEC/2023 á 09/DEC/2023
# 120       VCP      BEL  22/DEC/2023 á 30/DEC/2023  22/DEC/2023 á 30/DEC/2023
# 121       VCP      BEL  02/JAN/2023 á 09/MAR/2023  02/JAN/2023 á 09/MAR/2023
# ...       ...      ...                        ...                        ...
# 5002      VCP      CGR  07/JAN/2023 á 28/JAN/2023  07/JAN/2023 á 28/JAN/2023
# 5543      VCP      MCO  18/DEC/2023 á 19/DEC/2023  18/DEC/2023 á 19/DEC/2023
# 5550      VCP      MCO  12/JAN/2023 á 26/JAN/2023  12/JAN/2023 á 26/JAN/2023
# 5591      VCP      MCO  10/DEC/2023 á 17/DEC/2023  10/DEC/2023 á 17/DEC/2023
# 5606      VCP      MCO  20/JAN/2023 á 27/JAN/2023  20/JAN/2023 á 27/JAN/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR  FlightNumberArvl Trilho  \
# 117      09:50     00:00          E95       AD2020               NaN
# 118      09:50     00:00          E95       AD2020               NaN
# 119      09:50     00:00          E95       AD2020               NaN
# 120      09:50     00:00          E95       AD2020               NaN
# 121      15:40     00:00          E95       AD2020               NaN
# ...        ...       ...          ...          ...               ...    ...
# 5002     13:20     00:00          295       AD4877               NaN
# 5543     09:15     00:00          332       AD8706               NaN
# 5550     09:15     00:00          332       AD8706               NaN
# 5591     23:10     00:00          332       AD8708               NaN
# 5606     23:10     00:00          359       AD8708               NaN
#
#      Svc Type  Pax Week-Day
# 117         F  000  1234560
# 118         F  000  1230060
# 119         F  000  0004500
# 120         F  000  0004500
# 121         F  000  1234560
# ...       ...  ...      ...
# 5002        J  136  0000060
# 5543        J  242  1000007
# 5550        J  242  0004000
# 5591        J  271  0000060
# 5606        J  334  0030500
#
# [65 rows x 13 columns]

# %%
df_frame37 = df_orig.query('KeyX == 1  & Key == 37 & Kdept == 10')
df_frame37 = df_orig.query('KeyX == 1  & Key == 37')
df_frame37['FlightNumbeR'] = df_frame37['Arvl Sta']
df_frame37['Dept Sta'] = 'VCP'
df_frame37['Arvl Sta'] = df_frame37['Dept-Hora'].apply( lambda x: x[4:7])
df_frame37['Arvl Day'] = df_frame37['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame37['Dept Day'] = df_frame37['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame37['Trilho'] = ''
df_frame37['Pax'] = df_frame37['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame37['Pax-Subfleet'] = df_frame37['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame37['Arvl-Hora'] = '00:00'
df_frame37['Dept-Hora'] = df_frame37['Dept-Hora'].apply(lambda x: x[0:2] + ':' + x[2:4])
df_frame37 = df_frame37[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p4 = df_frame37
p4
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2239631803.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['FlightNumbeR'] = df_frame37['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2239631803.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Dept Sta'] = 'VCP'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2239631803.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Arvl Sta'] = df_frame37['Dept-Hora'].apply( lambda x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2239631803.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Arvl Day'] = df_frame37['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2239631803.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Dept Day'] = df_frame37['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2239631803.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2239631803.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Pax'] = df_frame37['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2239631803.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Pax-Subfleet'] = df_frame37['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2239631803.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Arvl-Hora'] = '00:00'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2239631803.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Dept-Hora'] = df_frame37['Dept-Hora'].apply(lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 139       VCP      BEL  16/DEC/2023  16/DEC/2023     05:40     00:00
# 240       VCP      IGU  23/NOV/2023  23/NOV/2023     08:40     00:00
# 327       VCP      CMG  15/FEB/2023  15/FEB/2023     09:20     00:00
# 329       VCP      CMG  22/FEB/2023  22/FEB/2023     09:20     00:00
# 357       VCP      SSA  30/DEC/2023  30/DEC/2023     14:00     00:00
# 436       VCP      FLN  12/NOV/2023  12/NOV/2023     09:05     00:00
# 442       VCP      FLN  03/DEC/2023  03/DEC/2023     09:05     00:00
# 802       VCP      CMG  27/FEB/2023  27/FEB/2023     09:20     00:00
# 1377      VCP      GIG  08/JAN/2023  08/JAN/2023     17:40     00:00
# 1379      VCP      GIG  19/FEB/2023  19/FEB/2023     17:40     00:00
# 1710      VCP      PHB  12/NOV/2023  12/NOV/2023     10:15     00:00
# 1713      VCP      JJD  15/NOV/2023  15/NOV/2023     10:55     00:00
# 1729      VCP      PHB  26/FEB/2023  26/FEB/2023     10:20     00:00
# 3088      VCP      CGR  30/OCT/2023  30/OCT/2023     08:20     00:00
# 3092      VCP      CGR  23/NOV/2023  23/NOV/2023     08:20     00:00
# 3590      VCP      NVT  31/OCT/2023  31/OCT/2023     08:15     00:00
# 3593      VCP      NVT  05/NOV/2023  05/NOV/2023     08:05     00:00
# 3897      VCP      MAO  30/OCT/2023  30/OCT/2023     22:25     00:00
# 3899      VCP      MAO  11/NOV/2023  11/NOV/2023     22:25     00:00
# 3903      VCP      MAO  04/DEC/2023  04/DEC/2023     22:25     00:00
# 4085      VCP      BSB  30/DEC/2023  30/DEC/2023     18:10     00:00
# 4515      VCP      BSB  30/DEC/2023  30/DEC/2023     13:10     00:00
# 4721      VCP      BEL  06/NOV/2023  06/NOV/2023     08:20     00:00
# 4723      VCP      BEL  26/NOV/2023  26/NOV/2023     08:15     00:00
# 4729      VCP      BEL  06/FEB/2023  06/FEB/2023     08:15     00:00
# 4989      VCP      CGR  05/NOV/2023  05/NOV/2023     13:20     00:00
# 5593      VCP      MCO  18/DEC/2023  18/DEC/2023     23:10     00:00
# 6265      VCP           25/MAR/2023  25/MAR/2023        -:     00:00
# 6374      VCP      SCL  28/DEC/2023  28/DEC/2023     11:55     00:00
# 6427      VCP      EZE  02/NOV/2023  02/NOV/2023     21:00     00:00
# 6662      VCP      BOG  13/DEC/2023  13/DEC/2023     02:30     00:00
# 6664      VCP      MIA  12/NOV/2023  12/NOV/2023     06:30     00:00
#
#      Pax-Subfleet FlightNumbeR  FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 139           E95       AD2030               NaN               F  000        -
# 240           32N       AD2406               NaN               J  174        -
# 327           E95       AD2514               NaN               J  118        -
# 329           295       AD2514               NaN               J  136        -
# 357           295       AD2536               NaN               J  136        -
# 436           32N       AD2613               NaN               J  174        -
# 442           32N       AD2613               NaN               J  174        -
# 802           E95       AD2690               NaN               J  118        -
# 1377          E95       AD2822               NaN               J  118        -
# 1379          E95       AD2822               NaN               J  118        -
# 1710          295       AD2904               NaN               J  136        -
# 1713          295       AD2904               NaN               J  136        -
# 1729          295       AD2904               NaN               J  136        -
# 3088          295       AD4282               NaN               J  136        -
# 3092          295       AD4282               NaN               J  136        -
# 3590          E95       AD4362               NaN               J  118        -
# 3593          E95       AD4362               NaN               J  118        -
# 3897          32N       AD4451               NaN               J  174        -
# 3899          32N       AD4451               NaN               J  174        -
# 3903          32N       AD4451               NaN               J  174        -
# 4085          32N       AD4548               NaN               J  174        -
# 4515          32N       AD4745               NaN               J  174        -
# 4721          32Q       AD4840               NaN               J  214        -
# 4723          32N       AD4840               NaN               J  174        -
# 4729          32N       AD4840               NaN               J  174        -
# 4989          295       AD4877               NaN               J  136        -
# 5593          359       AD8708               NaN               J  334        -
# 6265          77X            -               NaN               F  000        -
# 6374          76V       M38460               NaN               F  000        -
# 6427          76V       M38494               NaN               F  000        -
# 6662          763       W8926Z               NaN               H  000        -
# 6664          763       W81926               NaN               H  000        -

# %%
df_frame37 = df_orig.query('KeyX == 1  & Key == 37  & Kdept == 1')
df_frame37['FlightNumberArvl'] = df_frame37['Dept Sta'].apply( lambda x: x[1:8])
df_frame37['Dept Sta'] = df_frame37['Arvl-Hora'].apply( lambda x: x[3:6])
df_frame37['Arvl Sta'] = 'VCP'
df_frame37['Arvl Day'] = df_frame37['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame37['Dept Day'] = df_frame37['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame37['Trilho'] = ''
df_frame37['Pax'] = df_frame37['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame37['Pax-Subfleet'] = df_frame37['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame37['Arvl-Hora'] = df_frame37['Arvl-Hora'].apply(lambda x: x[6:8] + ':' + x[8:10])
df_frame37['Dept-Hora'] = '00:00'
df_frame37 = df_frame37[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p5 = df_frame37
p5
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3344277310.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['FlightNumberArvl'] = df_frame37['Dept Sta'].apply( lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3344277310.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Dept Sta'] = df_frame37['Arvl-Hora'].apply( lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3344277310.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Arvl Sta'] = 'VCP'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3344277310.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Arvl Day'] = df_frame37['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3344277310.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Dept Day'] = df_frame37['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3344277310.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3344277310.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Pax'] = df_frame37['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3344277310.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Pax-Subfleet'] = df_frame37['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3344277310.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Arvl-Hora'] = df_frame37['Arvl-Hora'].apply(lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3344277310.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame37['Dept-Hora'] = '00:00'
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 6265      MIA      VCP  25/MAR/2023  25/MAR/2023     00:00     19:35
#
#      Pax-Subfleet  FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 6265          77X           NaN            KE273               F  000        -

# %%
df_frame36 = df_orig.query('KeyX == 1  & Key == 36 & Kdept == 10')
df_frame36['FlightNumbeR'] = df_frame36['Arvl Sta']
df_frame36['Dept Sta'] = 'VCP'
df_frame36['Arvl Sta'] = df_frame36['Dept-Hora'].apply( lambda x: x[4:7])
df_frame36['Arvl Day'] = df_frame36['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame36['Dept Day'] = df_frame36['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame36['Trilho'] = ''
df_frame36['Pax'] = df_frame36['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame36['Pax-Subfleet'] = df_frame36['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame36['Arvl-Hora'] = '00:00'
df_frame36['Dept-Hora'] = df_frame36['Dept-Hora'].apply(lambda x: x[0:2] + ':' + x[2:4])
df_frame36 = df_frame36[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p6 = df_frame36
p6
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\103078588.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame36['FlightNumbeR'] = df_frame36['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\103078588.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame36['Dept Sta'] = 'VCP'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\103078588.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame36['Arvl Sta'] = df_frame36['Dept-Hora'].apply( lambda x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\103078588.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame36['Arvl Day'] = df_frame36['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\103078588.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame36['Dept Day'] = df_frame36['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\103078588.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame36['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\103078588.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame36['Pax'] = df_frame36['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\103078588.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame36['Pax-Subfleet'] = df_frame36['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\103078588.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame36['Arvl-Hora'] = '00:00'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\103078588.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame36['Dept-Hora'] = df_frame36['Dept-Hora'].apply(lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 6266      VCP      SCL  29/OCT/2023  29/OCT/2023     21:30     00:00
#
#      Pax-Subfleet FlightNumbeR  FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 6266          77X        KE274               NaN               F  000        -

# %%
df_frame46 = df_orig.query('KeyX == 1  & Key == 46 & Kdept == 1')
df_frame46['FlightNumberArvl'] = df_frame46['Dept Sta'].apply(lambda x: x[1:8])
df_frame46['Dept Sta'] = df_frame46['Arvl-Hora'].apply(lambda x: x[0:3])
df_frame46['FlightNumbeR'] = df_frame46['Arvl Sta']
df_frame46['Arvl Day'] = df_frame46['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame46['Dept Day'] = df_frame46['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame46['Trilho'] = ''
df_frame46['Pax'] = df_frame46['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame46['Pax-Subfleet'] = df_frame46['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame46['Dept-Hora'] = df_frame46['Arvl-Hora'].apply(lambda x: x[3:5]+ ':' + x[5:7])
df_frame46['Arvl-Hora'] = '00:00'
df_frame46['Arvl Sta'] = 'VCP'
df_frame46 = df_frame46[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p7 = df_frame46
p7
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1148540672.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['FlightNumberArvl'] = df_frame46['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1148540672.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Dept Sta'] = df_frame46['Arvl-Hora'].apply(lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1148540672.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['FlightNumbeR'] = df_frame46['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1148540672.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Arvl Day'] = df_frame46['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1148540672.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Dept Day'] = df_frame46['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1148540672.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1148540672.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Pax'] = df_frame46['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1148540672.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Pax-Subfleet'] = df_frame46['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1148540672.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Dept-Hora'] = df_frame46['Arvl-Hora'].apply(lambda x: x[3:5]+ ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1148540672.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Arvl-Hora'] = '00:00'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1148540672.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Arvl Sta'] = 'VCP'
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 67        MAO      VCP  30/OCT/2023 á 01/NOV/2023  30/OCT/2023 á 01/NOV/2023
# 70        MAO      VCP  03/NOV/2023 á 04/NOV/2023  03/NOV/2023 á 04/NOV/2023
# 71        MAO      VCP  05/NOV/2023 á 15/NOV/2023  05/NOV/2023 á 15/NOV/2023
# 72        MAO      VCP  07/NOV/2023 á 16/NOV/2023  07/NOV/2023 á 16/NOV/2023
# 73        MAO      VCP  10/NOV/2023 á 17/NOV/2023  10/NOV/2023 á 17/NOV/2023
# ...       ...      ...                        ...                        ...
# 6719      BSB      VCP  01/FEB/2023 á 24/MAR/2023  01/FEB/2023 á 24/MAR/2023
# 6727      MAO      VCP  11/MAR/2023 á 25/MAR/2023  11/MAR/2023 á 25/MAR/2023
# 6745      REC      VCP  19/JAN/2023 á 02/MAR/2023  19/JAN/2023 á 02/MAR/2023
# 6746      REC      VCP  07/MAR/2023 á 25/MAR/2023  07/MAR/2023 á 25/MAR/2023
# 6771      CWB      VCP  04/JAN/2023 á 10/JAN/2023  04/JAN/2023 á 10/JAN/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 67       15:20     00:00          73P            -           AD2003
# 70       14:50     00:00          73P            -           AD2003
# 71       15:35     00:00          73P            -           AD2003
# 72       16:35     00:00          73P            -           AD2003
# 73       16:05     00:00          73P            -           AD2003
# ...        ...       ...          ...          ...              ...    ...
# 6719     11:20     00:00          734            -           WD5801
# 6727     20:45     00:00          734            -           WD5803
# 6745     21:10     00:00          734            -           WD5807
# 6746     19:45     00:00          734            -           WD5807
# 6771     13:30     00:00          734            -           WD9621
#
#      Svc Type  Pax Week-Day
# 67          F  000  0200007
# 70          F  000  0004500
# 71          F  000  0200067
# 72          F  000  1030000
# 73          F  000  0004000
# ...       ...  ...      ...
# 6719        F  000  0030500
# 6727        F  000  0000060
# 6745        F  000  0204000
# 6746        F  000  0204060
# 6771        P  000  0230000
#
# [2263 rows x 13 columns]

# %%
df_frame35 = df_orig.query('KeyX == 1  & Key == 35 & Kdept == 1')
df_frame35['FlightNumberArvl'] = df_frame35['Dept Sta']
df_frame35['Dept Sta'] = df_frame35['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame35['Arvl Sta'] = 'VCP'
df_frame35['Arvl Day'] = df_frame35['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame35['Dept Day'] = df_frame35['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame35['Trilho'] = ''
df_frame35['Pax'] = df_frame35['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame35['Pax-Subfleet'] = df_frame35['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame35['Arvl-Hora'] = df_frame35['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame35['Dept-Hora'] = '00:00'
df_frame35 = df_frame35[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p8 = df_frame35
p8
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\444977694.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame35['FlightNumberArvl'] = df_frame35['Dept Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\444977694.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame35['Dept Sta'] = df_frame35['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\444977694.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame35['Arvl Sta'] = 'VCP'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\444977694.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame35['Arvl Day'] = df_frame35['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\444977694.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame35['Dept Day'] = df_frame35['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\444977694.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame35['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\444977694.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame35['Pax'] = df_frame35['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\444977694.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame35['Pax-Subfleet'] = df_frame35['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\444977694.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame35['Arvl-Hora'] = df_frame35['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\444977694.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame35['Dept-Hora'] = '00:00'
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 68        MAO      VCP  31/OCT/2023  31/OCT/2023     00:00     17:05
# 69        MAO      VCP  02/NOV/2023  02/NOV/2023     00:00     15:55
# 74        MAO      VCP  11/NOV/2023  11/NOV/2023     00:00     16:30
# 126       MAO      VCP  30/NOV/2023  30/NOV/2023     00:00     23:05
# 132       MAO      VCP  02/FEB/2023  02/FEB/2023     00:00     04:45
# ...       ...      ...          ...          ...       ...       ...
# 6770      BEL      VCP  15/DEC/2023  15/DEC/2023     00:00     18:15
# 6772      CWB      VCP  31/OCT/2023  31/OCT/2023     00:00     13:30
# 6773      POA      VCP  03/NOV/2023  03/NOV/2023     00:00     14:40
# 6774      CNF      VCP  17/NOV/2023  17/NOV/2023     00:00     13:35
# 6777      CGR      VCP  08/DEC/2023  08/DEC/2023     00:00     15:15
#
#      Pax-Subfleet  FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 68            73P           NaN          HAD2003               F  000        -
# 69            73P           NaN          HAD2003               F  000        -
# 74            73P           NaN          HAD2003               F  000        -
# 126           E95           NaN          HAD2021               F  000        -
# 132           E95           NaN          HAD2023               F  000        -
# ...           ...           ...              ...    ...      ...  ...      ...
# 6770          734           NaN          HWD9621               P  000        -
# 6772          734           NaN          HWD9622               P  000        -
# 6773          734           NaN          HWD9622               P  000        -
# 6774          734           NaN          HWD9622               P  000        -
# 6777          734           NaN          HWD9622               P  000        -
#
# [830 rows x 13 columns]

# %%
df_frame38 = df_orig.query('KeyX == 1  & Key == 38 & Kdept == 1')
df_frame38['FlightNumberArvl'] = df_frame38['Dept Sta'].apply(lambda x: x[1:8])
df_frame38['Dept Sta'] = df_frame38['Arvl-Hora'].apply( lambda x: x[3:6])
df_frame38['Arvl Sta'] = 'VCP'
df_frame38['Arvl Day'] = df_frame38['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame38['Dept Day'] = df_frame38['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame38['Trilho'] = ''
df_frame38['Pax'] = df_frame38['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame38['Pax-Subfleet'] = df_frame38['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame38['Arvl-Hora'] = df_frame38['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
df_frame38['Dept-Hora'] = '00:00'
df_frame38 = df_frame38[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p9 = df_frame38
p9
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1673626898.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame38['FlightNumberArvl'] = df_frame38['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1673626898.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame38['Dept Sta'] = df_frame38['Arvl-Hora'].apply( lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1673626898.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame38['Arvl Sta'] = 'VCP'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1673626898.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame38['Arvl Day'] = df_frame38['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1673626898.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame38['Dept Day'] = df_frame38['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1673626898.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame38['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1673626898.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame38['Pax'] = df_frame38['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1673626898.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame38['Pax-Subfleet'] = df_frame38['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1673626898.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame38['Arvl-Hora'] = df_frame38['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1673626898.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame38['Dept-Hora'] = '00:00'
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 109       MAO      VCP  31/OCT/2023  31/OCT/2023     00:00     23:30
# 113       MAO      VCP  09/DEC/2023  09/DEC/2023     00:00     23:30
# 115       MAO      VCP  16/DEC/2023  16/DEC/2023     00:00     23:10
# 250       IGU      VCP  23/NOV/2023  23/NOV/2023     00:00     12:35
# 326       BYO      VCP  15/FEB/2023  15/FEB/2023     00:00     15:35
# 328       BYO      VCP  22/FEB/2023  22/FEB/2023     00:00     15:35
# 366       SSA      VCP  30/DEC/2023  30/DEC/2023     00:00     19:40
# 898       BEL      VCP  26/NOV/2023  26/NOV/2023     00:00     20:40
# 905       BEL      VCP  06/FEB/2023  06/FEB/2023     00:00     20:40
# 1704      JJD      VCP  30/OCT/2023  30/OCT/2023     00:00     19:40
# 1709      JJD      VCP  06/NOV/2023  06/NOV/2023     00:00     19:30
# 1711      JJD      VCP  12/NOV/2023  12/NOV/2023     00:00     19:25
# 1712      PHB      VCP  15/NOV/2023  15/NOV/2023     00:00     19:50
# 1718      JJD      VCP  18/DEC/2023  18/DEC/2023     00:00     20:30
# 1730      JJD      VCP  26/FEB/2023  26/FEB/2023     00:00     19:45
# 2154      MAO      VCP  30/OCT/2023  30/OCT/2023     00:00     21:00
# 2155      MAO      VCP  31/OCT/2023  31/OCT/2023     00:00     20:45
# 2217      BSB      VCP  30/DEC/2023  30/DEC/2023     00:00     22:25
# 3925      FLN      VCP  12/NOV/2023  12/NOV/2023     00:00     12:25
# 3931      FLN      VCP  03/DEC/2023  03/DEC/2023     00:00     12:25
# 4282      GIG      VCP  22/NOV/2023  22/NOV/2023     00:00     21:00
# 4392      BSB      VCP  30/DEC/2023  30/DEC/2023     00:00     17:15
# 5786      SDU      VCP  30/JAN/2023  30/JAN/2023     00:00     14:10
# 6630      ASU      VCP  14/NOV/2023  14/NOV/2023     00:00     04:05
# 6649      ASU      VCP  31/OCT/2023  31/OCT/2023     00:00     10:55
#
#      Pax-Subfleet  FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 109           E95           NaN           AD2011               F  000        -
# 113           E95           NaN           AD2011               F  000        -
# 115           E95           NaN           AD2011               F  000        -
# 250           32N           NaN           AD2407               J  174        -
# 326           E95           NaN           AD2514               J  118        -
# 328           295           NaN           AD2514               J  136        -
# 366           295           NaN           AD2551               J  136        -
# 898           32N           NaN           AD2705               J  174        -
# 905           32N           NaN           AD2705               J  174        -
# 1704          295           NaN           AD2904               J  136        -
# 1709          295           NaN           AD2904               J  136        -
# 1711          295           NaN           AD2904               J  136        -
# 1712          295           NaN           AD2904               J  136        -
# 1718          295           NaN           AD2904               J  136        -
# 1730          295           NaN           AD2904               J  136        -
# 2154          32N           NaN           AD4013               J  174        -
# 2155          32N           NaN           AD4013               J  174        -
# 2217          32N           NaN           AD4021               J  174        -
# 3925          32N           NaN           AD4483               J  174        -
# 3931          32N           NaN           AD4483               J  174        -
# 4282          E95           NaN           AD4614               J  118        -
# 4392          32N           NaN           AD4696               J  174        -
# 5786          32N           NaN           AD9013               G  174        -
# 6630          76V           NaN           UC1713               F  000        -
# 6649          76V           NaN           UC1771               F  000        -

# %%
df_frame49 = df_orig.query('KeyX == 1  & Key == 49 & Kdept == 1')
df_frame49['FlightNumberArvl'] = df_frame49['Dept Sta'].apply(lambda x: x[1:8])
df_frame49['Dept Sta'] = df_frame49['Arvl-Hora'].apply( lambda x: x[3:6])
df_frame49['Arvl Sta'] = 'VCP'
df_frame49['Arvl Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame49['Dept Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame49['Trilho'] = ''
df_frame49['Pax'] = df_frame49['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame49['Pax-Subfleet'] = df_frame49['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame49['Arvl-Hora'] = df_frame49['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
df_frame49['Dept-Hora'] = '00:00'
df_frame49 = df_frame49[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p10 = df_frame49
p10
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\263375210.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['FlightNumberArvl'] = df_frame49['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\263375210.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Dept Sta'] = df_frame49['Arvl-Hora'].apply( lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\263375210.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Arvl Sta'] = 'VCP'
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\263375210.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Arvl Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\263375210.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Dept Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\263375210.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\263375210.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Pax'] = df_frame49['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\263375210.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Pax-Subfleet'] = df_frame49['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\263375210.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Arvl-Hora'] = df_frame49['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\263375210.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Dept-Hora'] = '00:00'
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 110       MAO      VCP  01/NOV/2023 á 29/NOV/2023  01/NOV/2023 á 29/NOV/2023
# 111       MAO      VCP  02/NOV/2023 á 22/MAR/2023  02/NOV/2023 á 22/MAR/2023
# 112       MAO      VCP  01/DEC/2023 á 08/DEC/2023  01/DEC/2023 á 08/DEC/2023
# 114       MAO      VCP  10/DEC/2023 á 25/MAR/2023  10/DEC/2023 á 25/MAR/2023
# 116       MAO      VCP  23/DEC/2023 á 24/MAR/2023  23/DEC/2023 á 24/MAR/2023
# 249       IGU      VCP  05/NOV/2023 á 28/JAN/2023  05/NOV/2023 á 28/JAN/2023
# 252       IGU      VCP  07/DEC/2023 á 14/DEC/2023  07/DEC/2023 á 14/DEC/2023
# 254       IGU      VCP  04/JAN/2023 á 25/JAN/2023  04/JAN/2023 á 25/JAN/2023
# 317       BYO      VCP  30/OCT/2023 á 09/NOV/2023  30/OCT/2023 á 09/NOV/2023
# 319       BYO      VCP  16/NOV/2023 á 30/NOV/2023  16/NOV/2023 á 30/NOV/2023
# 321       BYO      VCP  04/DEC/2023 á 28/DEC/2023  04/DEC/2023 á 28/DEC/2023
# 322       BYO      VCP  04/JAN/2023 á 08/FEB/2023  04/JAN/2023 á 08/FEB/2023
# 324       BYO      VCP  12/FEB/2023 á 05/MAR/2023  12/FEB/2023 á 05/MAR/2023
# 330       BYO      VCP  01/MAR/2023 á 22/MAR/2023  01/MAR/2023 á 22/MAR/2023
# 333       BYO      VCP  12/MAR/2023 á 19/MAR/2023  12/MAR/2023 á 19/MAR/2023
# 791       BYO      VCP  31/OCT/2023 á 11/NOV/2023  31/OCT/2023 á 11/NOV/2023
# 794       BYO      VCP  15/NOV/2023 á 31/JAN/2023  15/NOV/2023 á 31/JAN/2023
# 797       BYO      VCP  03/FEB/2023 á 17/FEB/2023  03/FEB/2023 á 17/FEB/2023
# 800       BYO      VCP  20/FEB/2023 á 24/FEB/2023  20/FEB/2023 á 24/FEB/2023
# 801       BYO      VCP  27/FEB/2023 á 24/MAR/2023  27/FEB/2023 á 24/MAR/2023
# 896       BEL      VCP  30/OCT/2023 á 31/OCT/2023  30/OCT/2023 á 31/OCT/2023
# 897       BEL      VCP  01/NOV/2023 á 25/NOV/2023  01/NOV/2023 á 25/NOV/2023
# 899       BEL      VCP  27/NOV/2023 á 02/DEC/2023  27/NOV/2023 á 02/DEC/2023
# 900       BEL      VCP  03/DEC/2023 á 24/DEC/2023  03/DEC/2023 á 24/DEC/2023
# 901       BEL      VCP  05/DEC/2023 á 03/FEB/2023  05/DEC/2023 á 03/FEB/2023
# 903       BEL      VCP  31/DEC/2023 á 25/MAR/2023  31/DEC/2023 á 25/MAR/2023
# 904       BEL      VCP  08/JAN/2023 á 19/MAR/2023  08/JAN/2023 á 19/MAR/2023
# 906       BEL      VCP  07/FEB/2023 á 24/MAR/2023  07/FEB/2023 á 24/MAR/2023
# 929       NVT      VCP  31/OCT/2023 á 11/NOV/2023  31/OCT/2023 á 11/NOV/2023
# 931       NVT      VCP  09/NOV/2023 á 14/DEC/2023  09/NOV/2023 á 14/DEC/2023
# 935       NVT      VCP  17/NOV/2023 á 16/DEC/2023  17/NOV/2023 á 16/DEC/2023
# 1706      PHB      VCP  31/OCT/2023 á 11/NOV/2023  31/OCT/2023 á 11/NOV/2023
# 1707      JJD      VCP  02/NOV/2023 á 28/DEC/2023  02/NOV/2023 á 28/DEC/2023
# 1715      PHB      VCP  18/NOV/2023 á 30/DEC/2023  18/NOV/2023 á 30/DEC/2023
# 1717      JJD      VCP  20/NOV/2023 á 11/DEC/2023  20/NOV/2023 á 11/DEC/2023
# 1719      PHB      VCP  02/JAN/2023 á 06/JAN/2023  02/JAN/2023 á 06/JAN/2023
# 1720      JJD      VCP  04/JAN/2023 á 25/JAN/2023  04/JAN/2023 á 25/JAN/2023
# 1723      JJD      VCP  08/JAN/2023 á 12/FEB/2023  08/JAN/2023 á 12/FEB/2023
# 1724      PHB      VCP  09/JAN/2023 á 13/FEB/2023  09/JAN/2023 á 13/FEB/2023
# 1725      JJD      VCP  08/FEB/2023 á 15/FEB/2023  08/FEB/2023 á 15/FEB/2023
# 1727      PHB      VCP  24/FEB/2023 á 27/FEB/2023  24/FEB/2023 á 27/FEB/2023
# 1771      CWB      VCP  03/NOV/2023 á 06/NOV/2023  03/NOV/2023 á 06/NOV/2023
# 1775      CWB      VCP  20/NOV/2023 á 27/NOV/2023  20/NOV/2023 á 27/NOV/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet  FlightNumbeR FlightNumberArvl Trilho  \
# 110      00:00     23:15          E95           NaN           AD2011
# 111      00:00     23:20          E95           NaN           AD2011
# 112      00:00     23:20          E95           NaN           AD2011
# 114      00:00     23:20          E95           NaN           AD2011
# 116      00:00     23:20          E95           NaN           AD2011
# 249      00:00     12:35          32N           NaN           AD2407
# 252      00:00     12:35          32N           NaN           AD2407
# 254      00:00     12:35          32N           NaN           AD2407
# 317      00:00     15:30          E95           NaN           AD2514
# 319      00:00     15:30          E95           NaN           AD2514
# 321      00:00     15:35          E95           NaN           AD2514
# 322      00:00     15:35          E95           NaN           AD2514
# 324      00:00     15:35          295           NaN           AD2514
# 330      00:00     15:35          E95           NaN           AD2514
# 333      00:00     15:35          E95           NaN           AD2514
# 791      00:00     15:30          E95           NaN           AD2690
# 794      00:00     15:30          E95           NaN           AD2690
# 797      00:00     15:30          E95           NaN           AD2690
# 800      00:00     15:30          295           NaN           AD2690
# 801      00:00     15:30          E95           NaN           AD2690
# 896      00:00     20:30          32Q           NaN           AD2705
# 897      00:00     20:40          32Q           NaN           AD2705
# 899      00:00     20:40          32Q           NaN           AD2705
# 900      00:00     20:45          32Q           NaN           AD2705
# 901      00:00     20:40          32Q           NaN           AD2705
# 903      00:00     20:45          32Q           NaN           AD2705
# 904      00:00     20:45          32Q           NaN           AD2705
# 906      00:00     20:40          32Q           NaN           AD2705
# 929      00:00     12:40          E95           NaN           AD2710
# 931      00:00     12:40          E95           NaN           AD2710
# 935      00:00     12:40          E95           NaN           AD2710
# 1706     00:00     20:25          295           NaN           AD2904
# 1707     00:00     19:55          295           NaN           AD2904
# 1715     00:00     20:25          295           NaN           AD2904
# 1717     00:00     19:30          295           NaN           AD2904
# 1719     00:00     20:45          295           NaN           AD2904
# 1720     00:00     20:10          295           NaN           AD2904
# 1723     00:00     19:45          295           NaN           AD2904
# 1724     00:00     20:50          295           NaN           AD2904
# 1725     00:00     20:10          295           NaN           AD2904
# 1727     00:00     20:50          295           NaN           AD2904
# 1771     00:00     18:15          E95           NaN           AD2916
# 1775     00:00     18:15          E95           NaN           AD2916
#
#      Svc Type  Pax Week-Day
# 110         F  000  1204560
# 111         F  000  0030000
# 112         F  000  1204560
# 114         F  000  1204060
# 116         F  000  0000500
# 249         J  174  0000060
# 252         J  174  0030000
# 254         J  174  0030000
# 317         J  118  0030007
# 319         J  118  0030007
# 321         J  118  0030007
# 322         J  118  0030007
# 324         J  136  0000007
# 330         J  118  0030000
# 333         J  118  0000007
# 791         J  118  1204500
# 794         J  118  1204500
# 797         J  118  1000500
# 800         J  136  1000500
# 801         J  118  1000500
# 896         J  214  1000007
# 897         J  214  1234567
# 899         J  214  1234507
# 900         J  214  0000067
# 901         J  214  1234500
# 903         J  214  0000060
# 904         J  214  0000007
# 906         J  214  1234500
# 929         J  118  1204560
# 931         J  118  0030000
# 935         J  118  1204560
# 1706        J  136  1000500
# 1707        J  136  0030000
# 1715        J  136  1000500
# 1717        J  136  0000007
# 1719        J  136  1000500
# 1720        J  136  0030000
# 1723        J  136  0000007
# 1724        J  136  1000500
# 1725        J  136  0030000
# 1727        J  136  1000500
# 1771        J  118  0004507
# 1775        J  118  0000007

# %%
df_frame45 = df_orig.query('KeyX == 2  & Key == 45 & Kdept == 7 & Karvl == 7')
df_frame45['FlightNumberArvl'] = df_frame45['Arvl Sta']
df_frame45['FlightNumbeR'] = df_frame45['Dept Sta'].apply(lambda x: x[1:8])
df_frame45['Dept Sta'] = df_frame45['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame45['Arvl Sta'] = df_frame45['Dept-Hora'].apply( lambda  x: x[4:7])
df_frame45['Arvl Day'] = df_frame45['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame45['Dept Day'] = df_frame45['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame45['Trilho'] = ''
df_frame45['Pax'] = df_frame45['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame45['Pax-Subfleet'] = df_frame45['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame45['Arvl-Hora'] = df_frame45['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame45['Dept-Hora'] = df_frame45['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame45 = df_frame45[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p11 = df_frame45
p11
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1205791223.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['FlightNumberArvl'] = df_frame45['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1205791223.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['FlightNumbeR'] = df_frame45['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1205791223.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Dept Sta'] = df_frame45['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1205791223.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Arvl Sta'] = df_frame45['Dept-Hora'].apply( lambda  x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1205791223.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Arvl Day'] = df_frame45['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1205791223.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Dept Day'] = df_frame45['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1205791223.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1205791223.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Pax'] = df_frame45['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1205791223.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Pax-Subfleet'] = df_frame45['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1205791223.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Arvl-Hora'] = df_frame45['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1205791223.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame45['Dept-Hora'] = df_frame45['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 4         EZE      MIA  28/DEC/2023  28/DEC/2023     13:10     11:25
# 5         EZE      MIA  04/JAN/2023  04/JAN/2023     13:00     11:25
# 27        MIA      MIA  30/OCT/2023  30/OCT/2023     09:40     07:35
# 28        MIA      MIA  06/NOV/2023  06/NOV/2023     10:40     07:35
# 31        MIA      MIA  01/JAN/2023  01/JAN/2023     11:45     09:35
# 6241      MIA      SCL  23/NOV/2023  23/NOV/2023     20:30     18:30
# 6245      MIA      SCL  10/DEC/2023  10/DEC/2023     09:40     07:40
# 6247      MIA      SCL  15/DEC/2023  15/DEC/2023     22:30     12:30
# 6255      MGA      MIA  03/NOV/2023  03/NOV/2023     17:00     02:00
# 6257      MIA      SCL  26/NOV/2023  26/NOV/2023     16:00     01:30
# 6473      SCL      BGI  13/DEC/2023  13/DEC/2023     15:30     13:25
# 6495      LIM      HHN  01/NOV/2023  01/NOV/2023     21:25     18:25
# 6497      LIM      MEX  01/NOV/2023  01/NOV/2023     18:55     02:25
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 4             76F        5X415            5X415              FF  000        -
# 5             76F        5X415            5X415              FF  000        -
# 27            76F        5X444            5X445              FF  000        -
# 28            76F        5X444            5X445              FF  000        -
# 31            76F        5X444            5X445              FF  000        -
# 6241          744        K4537            K4536              HH  000        -
# 6245          744        K4537            K4536              HH  000        -
# 6247          744        K4537            K4537              HH  000        -
# 6255          744        K4539            K4538              HH  000        -
# 6257          744        K4539            K4539              HH  000        -
# 6473          738        MB681            MB681              HP  000        -
# 6495          74Y        N8801            N8882              HP  000        -
# 6497          74Y        N8831            N8842              HP  000        -

# %%
df_frame46 = df_orig.query('KeyX == 2  & Key == 46 & Kdept == 8 & Karvl == 7')
df_frame46['FlightNumberArvl'] = df_frame46['Arvl Sta']
df_frame46['FlightNumbeR'] = df_frame46['Dept Sta'].apply(lambda x: x[1:8])
df_frame46['Dept Sta'] = df_frame46['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame46['Arvl Sta'] = df_frame46['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame46['Arvl Day'] = df_frame46['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame46['Dept Day'] = df_frame46['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame46['Trilho'] = ''
df_frame46['Pax'] = df_frame46['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame46['Pax-Subfleet'] = df_frame46['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame46['Arvl-Hora'] = df_frame46['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame46['Dept-Hora'] = df_frame46['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame46 = df_frame46[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p12 = df_frame46
p12
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4087133203.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['FlightNumberArvl'] = df_frame46['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4087133203.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['FlightNumbeR'] = df_frame46['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4087133203.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Dept Sta'] = df_frame46['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4087133203.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Arvl Sta'] = df_frame46['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4087133203.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Arvl Day'] = df_frame46['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4087133203.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Dept Day'] = df_frame46['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4087133203.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4087133203.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Pax'] = df_frame46['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4087133203.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Pax-Subfleet'] = df_frame46['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4087133203.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Arvl-Hora'] = df_frame46['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4087133203.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame46['Dept-Hora'] = df_frame46['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 18        EZE      MIA  09/JAN/2023  09/JAN/2023     04:30     22:45
# 19        EZE      MIA  16/JAN/2023  16/JAN/2023     03:05     22:45
# 20        EZE      MIA  23/JAN/2023  23/JAN/2023     04:30     22:45
# 21        EZE      MIA  30/JAN/2023  30/JAN/2023     03:05     22:45
# 23        EZE      MIA  20/FEB/2023  20/FEB/2023     03:05     22:45
# 24        EZE      MIA  27/FEB/2023  27/FEB/2023     04:30     22:45
# 25        EZE      MIA  06/MAR/2023  06/MAR/2023     03:05     22:45
# 6239      MIA      UIO  07/NOV/2023  07/NOV/2023     09:30     19:30
# 6240      MIA      UIO  15/NOV/2023  15/NOV/2023     05:00     10:30
# 6242      PTY      UIO  28/NOV/2023  28/NOV/2023     07:00     17:30
# 6243      MIA      UIO  05/DEC/2023  05/DEC/2023     06:30     11:00
# 6244      MIA      SCL  08/DEC/2023  08/DEC/2023     02:30     14:00
# 6246      MIA      UIO  13/DEC/2023  13/DEC/2023     11:30     21:30
# 6248      MIA      UIO  19/DEC/2023  19/DEC/2023     06:30     17:00
# 6250      MIA      SCL  30/DEC/2023  30/DEC/2023     04:30     14:15
# 6251      MIA      SCL  05/JAN/2023  05/JAN/2023     02:30     12:30
# 6252      MIA      SCL  11/JAN/2023  11/JAN/2023     09:00     18:00
# 6254      MIA      UIO  31/OCT/2023  31/OCT/2023     06:00     10:30
# 6256      MIA      MIA  10/NOV/2023  10/NOV/2023     04:45     14:00
# 6258      MIA      UIO  09/JAN/2023  09/JAN/2023     12:30     22:30
# 6496      LIM      MIA  02/NOV/2023  02/NOV/2023     20:00     18:25
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 18            76F        5X417            5X417              FF  000        -
# 19            76F        5X417            5X417              FF  000        -
# 20            76F        5X417            5X417              FF  000        -
# 21            76F        5X417            5X417              FF  000        -
# 23            76F        5X417            5X417              FF  000        -
# 24            76F        5X417            5X417              FF  000        -
# 25            76F        5X417            5X417              FF  000        -
# 6239          744        K4537            K4536              HH  000        -
# 6240          744        K4537            K4536              HH  000        -
# 6242          744        K4537            K4536              HH  000        -
# 6243          744        K4537            K4536              HH  000        -
# 6244          744        K4537            K4536              HH  000        -
# 6246          744        K4537            K4536              HH  000        -
# 6248          744        K4537            K4536              HH  000        -
# 6250          744        K4537            K4537              HH  000        -
# 6251          744        K4537            K4537              HH  000        -
# 6252          744        K4537            K4536              HH  000        -
# 6254          744        K4539            K4538              HH  000        -
# 6256          744        K4539            K4538              HH  000        -
# 6258          744        K4539            K4538              HH  000        -
# 6496          74Y        N8802            N8874              HH  000        -

# %%
df_frame47 = df_orig.query('KeyX == 2  & Key == 47 & Kdept == 7 & Karvl == 7')
df_frame47['FlightNumberArvl'] = df_frame47['Arvl Sta']
df_frame47['FlightNumbeR'] = df_frame47['Dept Sta'].apply(lambda x: x[1:8])
df_frame47['Dept Sta'] = df_frame47['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame47['Arvl Sta'] = df_frame47['Dept-Hora'].apply( lambda  x: x[4:8])
df_frame47['Arvl Day'] = df_frame47['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame47['Dept Day'] = df_frame47['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame47['Trilho'] = ''
df_frame47['Pax'] = df_frame47['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame47['Pax-Subfleet'] = df_frame47['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame47['Arvl-Hora'] = df_frame47['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame47['Dept-Hora'] = df_frame47['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame47 = df_frame47[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p13 = df_frame47
p13
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2098274376.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame47['FlightNumberArvl'] = df_frame47['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2098274376.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame47['FlightNumbeR'] = df_frame47['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2098274376.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame47['Dept Sta'] = df_frame47['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2098274376.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame47['Arvl Sta'] = df_frame47['Dept-Hora'].apply( lambda  x: x[4:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2098274376.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame47['Arvl Day'] = df_frame47['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2098274376.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame47['Dept Day'] = df_frame47['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2098274376.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame47['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2098274376.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame47['Pax'] = df_frame47['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2098274376.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame47['Pax-Subfleet'] = df_frame47['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2098274376.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame47['Arvl-Hora'] = df_frame47['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2098274376.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame47['Dept-Hora'] = df_frame47['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 42        LIM      MIA  02/NOV/2023  02/NOV/2023     04:05     01:05
# 45        ORD      SID  14/NOV/2023  14/NOV/2023     15:30     12:30
# 6269      MIA      MDE  31/OCT/2023  31/OCT/2023     22:15     21:05
# 6270      MIA      SCL  07/NOV/2023  07/NOV/2023     23:15     22:05
# 6272      MIA      BOG  17/NOV/2023  17/NOV/2023     08:40     07:30
# ...       ...      ...          ...          ...       ...       ...
# 6645      MIA      SCL  26/NOV/2023  26/NOV/2023     10:30     09:20
# 6653      MIA      SCL  16/JAN/2023  16/JAN/2023     08:30     07:20
# 6655      MIA      SCL  17/DEC/2023  17/DEC/2023     10:25     09:15
# 6656      SCL      MVD  13/DEC/2023  13/DEC/2023     14:30     13:30
# 6657      SCL      ASU  11/NOV/2023  11/NOV/2023     10:30     09:30
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 42            744       5Y8094           5Y8093              HH  000        -
# 45            74N       7L4982           7L3010              PH  000        -
# 6269          76V       L71527           L71527              FF  000        -
# 6270          76V       L71527           L71527              FF  000        -
# 6272          76V       L71813           L71813              FF  000        -
# ...           ...          ...              ...    ...      ...  ...      ...
# 6645          76V       UC1741           UC1741              FF  000        -
# 6653          76V       UC1771           UC1771              FF  000        -
# 6655          76V       UC1921           UC1921              FF  000        -
# 6656          72Y       VZ1212           VZ8764              HP  000        -
# 6657          72Y       VZ7522           VZ7828              HP  000        -
#
# [71 rows x 13 columns]

# %%
df_frame48 = df_orig.query('KeyX == 2  & Key == 48 & Kdept == 10 & Karvl == 7')
df_frame48['FlightNumberArvl'] = df_frame48['Arvl Sta']
df_frame48['FlightNumbeR'] = df_frame48['Dept Sta'].apply(lambda x: x[1:8])
df_frame48['Dept Sta'] = df_frame48['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame48['Arvl Sta'] = df_frame48['Dept-Hora'].apply( lambda  x: x[4:8])
df_frame48['Arvl Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame48['Dept Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame48['Trilho'] = ''
df_frame48['Pax'] = df_frame48['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame48['Pax-Subfleet'] = df_frame48['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame48['Arvl-Hora'] = df_frame48['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame48['Dept-Hora'] = df_frame48['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame48 = df_frame48[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p14 = df_frame48
p14
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3188736179.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['FlightNumberArvl'] = df_frame48['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3188736179.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['FlightNumbeR'] = df_frame48['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3188736179.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept Sta'] = df_frame48['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3188736179.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl Sta'] = df_frame48['Dept-Hora'].apply( lambda  x: x[4:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3188736179.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3188736179.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3188736179.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3188736179.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Pax'] = df_frame48['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3188736179.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Pax-Subfleet'] = df_frame48['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3188736179.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl-Hora'] = df_frame48['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3188736179.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept-Hora'] = df_frame48['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#   Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 1      EZE     BOGM  02/NOV/2023  02/NOV/2023     10:50     09:15
# 9      MIA     SCLE  30/OCT/2023  30/OCT/2023     18:00     16:20
#
#   Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 1          76F        5X415            5X415              FF  000        -
# 9          76F        5X416            5X416              FF  000        -

# %%
df_frame48 = df_orig.query('KeyX == 2  & Key == 48 & Kdept == 8 & Karvl == 7')
df_frame48['FlightNumberArvl'] = df_frame48['Arvl Sta']
df_frame48['FlightNumbeR'] = df_frame48['Dept Sta'].apply(lambda x: x[1:8])
df_frame48['Dept Sta'] = df_frame48['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame48['Arvl Sta'] = df_frame48['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame48['Arvl Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame48['Dept Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame48['Trilho'] = ''
df_frame48['Pax'] = df_frame48['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame48['Pax-Subfleet'] = df_frame48['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame48['Arvl-Hora'] = df_frame48['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame48['Dept-Hora'] = df_frame48['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame48 = df_frame48[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p15 = df_frame48
p15
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2747765488.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['FlightNumberArvl'] = df_frame48['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2747765488.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['FlightNumbeR'] = df_frame48['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2747765488.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept Sta'] = df_frame48['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2747765488.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl Sta'] = df_frame48['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2747765488.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2747765488.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2747765488.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2747765488.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Pax'] = df_frame48['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2747765488.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Pax-Subfleet'] = df_frame48['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2747765488.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl-Hora'] = df_frame48['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2747765488.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept-Hora'] = df_frame48['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 41        LIM      MIA  31/OCT/2023  31/OCT/2023     01:20     22:15
# 6308      MIA      BOG  05/NOV/2023  05/NOV/2023     00:50     23:40
# 6309      MIA      BOG  31/DEC/2023  31/DEC/2023     00:50     23:40
# 6514      MIA      BOG  06/DEC/2023  06/DEC/2023     00:15     22:45
# 6518      MIA      BOG  02/NOV/2023  02/NOV/2023     00:15     22:45
# 6524      MIA      BOG  10/DEC/2023  10/DEC/2023     00:30     23:00
# 6527      MIA      BOG  06/JAN/2023  06/JAN/2023     01:30     24:00
# 6535      CWB      BOG  24/NOV/2023  24/NOV/2023     01:00     23:30
# 6538      CWB      BOG  08/DEC/2023  08/DEC/2023     00:30     22:45
# 6541      CWB      BOG  22/DEC/2023  22/DEC/2023     00:15     22:35
# 6543      CWB      BOG  05/JAN/2023  05/JAN/2023     01:00     23:30
# 6545      CWB      BOG  15/JAN/2023  15/JAN/2023     00:45     23:15
# 6550      ASU      BOG  01/JAN/2023  01/JAN/2023     00:15     22:45
# 6551      ASU      BOG  04/JAN/2023  04/JAN/2023     00:30     23:00
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 41            744       5Y8092           5Y8093              HH  000        -
# 6308          76V       L72861           L72861              FF  000        -
# 6309          76V       L72861           L72861              FF  000        -
# 6514          332       QT4051           QT4052              FF  000        -
# 6518          332       QT4053           QT4054              FF  000        -
# 6524          332       QT4053           QT4054              FF  000        -
# 6527          332       QT4053           QT4054              FF  000        -
# 6535          332       QT4055           QT4060              FF  000        -
# 6538          332       QT4055           QT4060              FF  000        -
# 6541          332       QT4055           QT4060              FF  000        -
# 6543          332       QT4055           QT4060              FF  000        -
# 6545          332       QT4055           QT4060              FF  000        -
# 6550          332       QT4087           QT4060              FF  000        -
# 6551          332       QT4089           QT4054              FF  000        -

# %%
df_frame48 = df_orig.query('KeyX == 2  & Key == 48 & Kdept == 7 & Karvl == 10')
df_frame48['FlightNumberArvl'] = df_frame48['Arvl Sta']
df_frame48['FlightNumbeR'] = df_frame48['Dept Sta'].apply(lambda x: x[1:8])
df_frame48['Dept Sta'] = df_frame48['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame48['Arvl Sta'] = df_frame48['Dept-Hora'].apply( lambda  x: x[4:8])
df_frame48['Arvl Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame48['Dept Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame48['Trilho'] = ''
df_frame48['Pax'] = df_frame48['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame48['Pax-Subfleet'] = df_frame48['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame48['Arvl-Hora'] = df_frame48['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
df_frame48['Dept-Hora'] = df_frame48['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame48 = df_frame48[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p16 = df_frame48
p16
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4223453349.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['FlightNumberArvl'] = df_frame48['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4223453349.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['FlightNumbeR'] = df_frame48['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4223453349.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept Sta'] = df_frame48['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4223453349.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl Sta'] = df_frame48['Dept-Hora'].apply( lambda  x: x[4:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4223453349.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4223453349.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept Day'] = df_frame48['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4223453349.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4223453349.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Pax'] = df_frame48['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4223453349.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Pax-Subfleet'] = df_frame48['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4223453349.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Arvl-Hora'] = df_frame48['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\4223453349.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame48['Dept-Hora'] = df_frame48['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 5991      ACC      LGG  21/NOV/2023  21/NOV/2023     07:45     04:45
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 5991          74Y        CC698            CC647              PH  000        -

# %%
df_frame49 = df_orig.query('KeyX == 2  & Key == 49 & Kdept == 11 & Karvl == 7')
df_frame49['FlightNumberArvl'] = df_frame49['Arvl Sta']
df_frame49['FlightNumbeR'] = df_frame49['Dept Sta'].apply(lambda x: x[1:8])
df_frame49['Dept Sta'] = df_frame49['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame49['Arvl Sta'] = df_frame49['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame49['Arvl Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame49['Dept Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame49['Trilho'] = ''
df_frame49['Pax'] = df_frame49['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame49['Pax-Subfleet'] = df_frame49['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame49['Arvl-Hora'] = df_frame49['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame49['Dept-Hora'] = df_frame49['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame49 = df_frame49[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p17 = df_frame49
p17
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3846878215.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['FlightNumberArvl'] = df_frame49['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3846878215.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['FlightNumbeR'] = df_frame49['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3846878215.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Dept Sta'] = df_frame49['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3846878215.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Arvl Sta'] = df_frame49['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3846878215.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Arvl Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3846878215.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Dept Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3846878215.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3846878215.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Pax'] = df_frame49['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3846878215.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Pax-Subfleet'] = df_frame49['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3846878215.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Arvl-Hora'] = df_frame49['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3846878215.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Dept-Hora'] = df_frame49['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#    Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 14      EZE      BOG  31/OCT/2023  31/OCT/2023     00:30     22:45
#
#    Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 14          76F        5X417            5X417              FF  000        -

# %%
df_frame49 = df_orig.query('KeyX == 2  & Key == 49 & Kdept == 7 & Karvl == 7')
df_frame49['FlightNumberArvl'] = df_frame49['Arvl Sta']
df_frame49['FlightNumbeR'] = df_frame49['Dept Sta'].apply(lambda x: x[1:8])
df_frame49['Dept Sta'] = df_frame49['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame49['Arvl Sta'] = df_frame49['Dept-Hora'].apply( lambda  x: x[4:8])
df_frame49['Arvl Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame49['Dept Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame49['Trilho'] = ''
df_frame49['Pax'] = df_frame49['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame49['Pax-Subfleet'] = df_frame49['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame49['Arvl-Hora'] = df_frame49['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame49['Dept-Hora'] = df_frame49['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame49 = df_frame49[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p18 = df_frame49
p18
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2910859617.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['FlightNumberArvl'] = df_frame49['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2910859617.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['FlightNumbeR'] = df_frame49['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2910859617.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Dept Sta'] = df_frame49['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2910859617.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Arvl Sta'] = df_frame49['Dept-Hora'].apply( lambda  x: x[4:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2910859617.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Arvl Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2910859617.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Dept Day'] = df_frame49['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2910859617.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2910859617.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Pax'] = df_frame49['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2910859617.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Pax-Subfleet'] = df_frame49['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2910859617.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Arvl-Hora'] = df_frame49['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2910859617.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame49['Dept-Hora'] = df_frame49['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 46        EZE      LET  14/DEC/2023  14/DEC/2023     14:00     11:30
# 6238      EZE      FRA  18/MAR/2023  18/MAR/2023     13:30     11:30
# 6561      VVI      VVI  08/JAN/2023  08/JAN/2023     04:30     01:30
# 6562      VVI      VVI  12/JAN/2023  12/JAN/2023     07:00     04:30
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 46            73P      ACL1166          ACL1165              HP  000        -
# 6238          77X      GEC8267          GEC8267              FF  000        -
# 6561          735      RER9511          RER9510              CP  120        -
# 6562          735      RER9511          RER9510              CP  120        -

# %%
df_frame50 = df_orig.query('KeyX == 2  & Key == 50 & Kdept == 10 & Karvl == 7')
df_frame50['FlightNumberArvl'] = df_frame50['Arvl Sta']
df_frame50['FlightNumbeR'] = df_frame50['Dept Sta'].apply(lambda x: x[1:8])
df_frame50['Dept Sta'] = df_frame50['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame50['Arvl Sta'] = df_frame50['Dept-Hora'].apply( lambda  x: x[4:7])
df_frame50['Arvl Day'] = df_frame50['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame50['Dept Day'] = df_frame50['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame50['Trilho'] = ''
df_frame50['Pax'] = df_frame50['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame50['Pax-Subfleet'] = df_frame50['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame50['Arvl-Hora'] = df_frame50['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame50['Dept-Hora'] = df_frame50['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame50 = df_frame50[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p19 = df_frame50
p19
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3901143344.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['FlightNumberArvl'] = df_frame50['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3901143344.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['FlightNumbeR'] = df_frame50['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3901143344.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Dept Sta'] = df_frame50['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3901143344.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Arvl Sta'] = df_frame50['Dept-Hora'].apply( lambda  x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3901143344.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Arvl Day'] = df_frame50['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3901143344.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Dept Day'] = df_frame50['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3901143344.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3901143344.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Pax'] = df_frame50['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3901143344.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Pax-Subfleet'] = df_frame50['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3901143344.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Arvl-Hora'] = df_frame50['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3901143344.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Dept-Hora'] = df_frame50['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 6267      MIA      CWB  18/NOV/2023  18/NOV/2023     13:40     12:30
# 6268      MIA      ASU  23/DEC/2023  23/DEC/2023     19:55     18:45
# 6283      MIA      AGT  18/NOV/2023  18/NOV/2023     07:45     06:35
# 6294      MIA      MVD  16/JAN/2023  16/JAN/2023     16:45     15:35
# 6295      MIA      CNF  01/NOV/2023  01/NOV/2023     23:30     22:20
# 6296      MIA      CNF  09/NOV/2023  09/NOV/2023     05:40     04:30
# 6307      MIA      ASU  16/DEC/2023  16/DEC/2023     08:10     07:00
# 6316      MIA      AGT  09/JAN/2023  09/JAN/2023     10:25     09:15
# 6318      MAO      EZE  09/NOV/2023  09/NOV/2023     21:00     17:30
# 6330      MIA      EZE  16/NOV/2023  16/NOV/2023     21:00     17:45
# 6331      MIA      EZE  23/NOV/2023  23/NOV/2023     21:00     16:20
# 6332      MIA      EZE  30/NOV/2023  30/NOV/2023     21:55     20:40
# 6333      MIA      BOG  01/DEC/2023  01/DEC/2023     11:10     08:50
# 6334      MIA      EZE  07/DEC/2023  07/DEC/2023     21:00     19:10
# 6335      MIA      EZE  14/DEC/2023  14/DEC/2023     21:00     19:15
# 6337      MIA      EZE  28/DEC/2023  28/DEC/2023     21:00     16:40
# 6339      MIA      EZE  11/JAN/2023  11/JAN/2023     21:00     19:55
# 6357      MIA      MDE  14/JAN/2023  14/JAN/2023     08:00     06:00
# 6364      MIA      AGT  11/DEC/2023  11/DEC/2023     05:00     01:20
# 6376      MIA      EZE  07/NOV/2023  07/NOV/2023     21:00     17:45
# 6446      SCL      UIO  06/JAN/2023  06/JAN/2023     11:20     07:55
# 6457      VIX      UIO  18/NOV/2023  18/NOV/2023     16:45     15:35
# 6458      VIX      EZE  22/NOV/2023  22/NOV/2023     21:00     14:25
# 6459      EZE      EZE  17/NOV/2023  17/NOV/2023     21:00     05:15
# 6507      MEX      LAX  02/NOV/2023  02/NOV/2023     19:45     17:40
# 6565      MIA      UIO  13/DEC/2023  13/DEC/2023     11:05     08:45
# 6566      GIG      UIO  14/DEC/2023  14/DEC/2023     08:50     07:40
# 6622      MIA      EZE  07/JAN/2023  07/JAN/2023     03:30     02:20
# 6625      MIA      POA  05/DEC/2023  05/DEC/2023     16:20     15:10
# 6628      MIA      AGT  04/DEC/2023  04/DEC/2023     17:45     16:35
# 6632      MIA      CWB  25/NOV/2023  25/NOV/2023     08:10     06:55
# 6644      MIA      FLN  18/NOV/2023  18/NOV/2023     11:30     10:20
# 6646      MIA      FLN  02/DEC/2023  02/DEC/2023     09:05     07:55
# 6647      MIA      FLN  13/JAN/2023  13/JAN/2023     05:50     04:40
# 6648      MIA      CWB  16/JAN/2023  16/JAN/2023     05:50     04:40
# 6652      MIA      CWB  05/DEC/2023  05/DEC/2023     06:45     02:30
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 6267          76V       L71524           L71524              FF  000        -
# 6268          76V       L71524           L71524              FF  000        -
# 6283          76V       L71819           L71819              FF  000        -
# 6294          76V       L72812           L72812              FF  000        -
# 6295          76V       L72825           L72825              FF  000        -
# 6296          76V       L72825           L72825              FF  000        -
# 6307          76V       L72845           L72845              FF  000        -
# 6316          76V       L72897           L72897              FF  000        -
# 6318          76V       M36559           M38494              FF  000        -
# 6330          76V       M38421           M38494              FF  000        -
# 6331          76V       M38421           M38494              FF  000        -
# 6332          76V       M38421           M38494              FF  000        -
# 6333          76V       M38421           M38440              FF  000        -
# 6334          76V       M38421           M38494              FF  000        -
# 6335          76V       M38421           M38494              FF  000        -
# 6337          76V       M38421           M38494              FF  000        -
# 6339          76V       M38421           M38494              FF  000        -
# 6357          76V       M38441           M39834              FF  000        -
# 6364          76V       M38443           M38472              FF  000        -
# 6376          76V       M38471           M38490              FF  000        -
# 6446          76V       M38497           M38430              FF  000        -
# 6457          76V       M39829           M38430              FF  000        -
# 6458          76V       M39831           M38492              FF  000        -
# 6459          76V       M39832           M38496              FF  000        -
# 6507          77X       QR8874           QR8875              HA  000        -
# 6565          76V       UC1105           UC1904              FF  000        -
# 6566          76V       UC1105           UC1804              FF  000        -
# 6622          76V       UC1524           UC1524              FF  000        -
# 6625          76V       UC1527           UC1527              FF  000        -
# 6628          76V       UC1609           UC1609              FF  000        -
# 6632          76V       UC1721           UC1721              FF  000        -
# 6644          76V       UC1741           UC1741              FF  000        -
# 6646          76V       UC1741           UC1741              FF  000        -
# 6647          76V       UC1741           UC1741              FF  000        -
# 6648          76V       UC1761           UC1761              FF  000        -
# 6652          76V       UC1771           UC1771              FF  000        -

# %%
df_frame50 = df_orig.query('KeyX == 2  & Key == 50 & Kdept == 7 & Karvl == 10')
df_frame50['FlightNumberArvl'] = df_frame50['Arvl Sta']
df_frame50['FlightNumbeR'] = df_frame50['Dept Sta'].apply(lambda x: x[1:8])
df_frame50['Dept Sta'] = df_frame50['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame50['Arvl Sta'] = df_frame50['Dept-Hora'].apply( lambda  x: x[4:7])
df_frame50['Arvl Day'] = df_frame50['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame50['Dept Day'] = df_frame50['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame50['Trilho'] = ''
df_frame50['Pax'] = df_frame50['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame50['Pax-Subfleet'] = df_frame50['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame50['Arvl-Hora'] = df_frame50['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
df_frame50['Dept-Hora'] = df_frame50['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame50 = df_frame50[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p20 = df_frame50
p20
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2298505629.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['FlightNumberArvl'] = df_frame50['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2298505629.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['FlightNumbeR'] = df_frame50['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2298505629.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Dept Sta'] = df_frame50['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2298505629.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Arvl Sta'] = df_frame50['Dept-Hora'].apply( lambda  x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2298505629.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Arvl Day'] = df_frame50['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2298505629.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Dept Day'] = df_frame50['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2298505629.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2298505629.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Pax'] = df_frame50['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2298505629.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Pax-Subfleet'] = df_frame50['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2298505629.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Arvl-Hora'] = df_frame50['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2298505629.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame50['Dept-Hora'] = df_frame50['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 6273      BOG      BOG  24/NOV/2023  24/NOV/2023     11:50     10:40
# 6274      BOG      BOG  08/DEC/2023  08/DEC/2023     10:25     09:15
# 6275      BOG      BOG  22/DEC/2023  22/DEC/2023     14:55     13:45
# 6290      MIA      BOG  31/OCT/2023  31/OCT/2023     09:55     08:45
# 6291      MIA      BOG  06/NOV/2023  06/NOV/2023     22:50     21:45
# ...       ...      ...          ...          ...       ...       ...
# 6633      MIA      SCL  29/NOV/2023  29/NOV/2023     21:10     20:00
# 6634      MIA      SCL  06/DEC/2023  06/DEC/2023     22:55     21:45
# 6635      MIA      SCL  11/JAN/2023  11/JAN/2023     08:20     07:10
# 6650      SCL      UIO  14/NOV/2023  14/NOV/2023     05:40     04:30
# 6654      MIA      SCL  07/DEC/2023  07/DEC/2023     06:45     05:35
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 6273          76V       L71813           L71813              FF  000        -
# 6274          76V       L71813           L71813              FF  000        -
# 6275          76V       L71813           L71813              FF  000        -
# 6290          76V       L71827           L71827              FF  000        -
# 6291          76V       L71830           L71827              FF  000        -
# ...           ...          ...              ...    ...      ...  ...      ...
# 6633          76V       UC1721           UC1721              FF  000        -
# 6634          76V       UC1721           UC1721              FF  000        -
# 6635          76V       UC1721           UC1721              FF  000        -
# 6650          76V       UC1771           UC1771              FF  000        -
# 6654          76V       UC1905           UC1905              FF  000        -
#
# [66 rows x 13 columns]

# %%
df_frame51 = df_orig.query('KeyX == 2  & Key == 51 & Kdept == 11 & Karvl == 7')
df_frame51['FlightNumberArvl'] = df_frame51['Arvl Sta']
df_frame51['FlightNumbeR'] = df_frame51['Dept Sta'].apply(lambda x: x[1:8])
df_frame51['Dept Sta'] = df_frame51['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame51['Arvl Sta'] = df_frame51['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame51['Arvl Day'] = df_frame51['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame51['Dept Day'] = df_frame51['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame51['Trilho'] = ''
df_frame51['Pax'] = df_frame51['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame51['Pax-Subfleet'] = df_frame51['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame51['Arvl-Hora'] = df_frame51['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame51['Dept-Hora'] = df_frame51['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame51 = df_frame51[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p21 = df_frame51
p21
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1919260747.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame51['FlightNumberArvl'] = df_frame51['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1919260747.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame51['FlightNumbeR'] = df_frame51['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1919260747.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame51['Dept Sta'] = df_frame51['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1919260747.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame51['Arvl Sta'] = df_frame51['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1919260747.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame51['Arvl Day'] = df_frame51['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1919260747.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame51['Dept Day'] = df_frame51['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1919260747.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame51['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1919260747.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame51['Pax'] = df_frame51['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1919260747.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame51['Pax-Subfleet'] = df_frame51['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1919260747.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame51['Arvl-Hora'] = df_frame51['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1919260747.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame51['Dept-Hora'] = df_frame51['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 6320      MAO      CCS  12/JAN/2023  12/JAN/2023     04:30     12:45
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 6320          76V       M36577           M38430              FF  000        -

# %%
df_frame52 = df_orig.query('KeyX == 2  & Key == 52 & Kdept == 11 & Karvl == 10')
df_frame52['FlightNumberArvl'] = df_frame52['Arvl Sta']
df_frame52['FlightNumbeR'] = df_frame52['Dept Sta'].apply(lambda x: x[1:8])
df_frame52['Dept Sta'] = df_frame52['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame52['Arvl Sta'] = df_frame52['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame52['Arvl Day'] = df_frame52['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame52['Dept Day'] = df_frame52['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame52['Trilho'] = ''
df_frame52['Pax'] = df_frame52['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame52['Pax-Subfleet'] = df_frame52['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame52['Arvl-Hora'] = df_frame52['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
df_frame52['Dept-Hora'] = df_frame52['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame52 = df_frame52[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p22 = df_frame52
p22
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\654371735.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['FlightNumberArvl'] = df_frame52['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\654371735.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['FlightNumbeR'] = df_frame52['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\654371735.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Dept Sta'] = df_frame52['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\654371735.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Arvl Sta'] = df_frame52['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\654371735.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Arvl Day'] = df_frame52['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\654371735.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Dept Day'] = df_frame52['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\654371735.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\654371735.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Pax'] = df_frame52['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\654371735.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Pax-Subfleet'] = df_frame52['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\654371735.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Arvl-Hora'] = df_frame52['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\654371735.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Dept-Hora'] = df_frame52['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#    Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 44      BOG      MAO  09/DEC/2023  09/DEC/2023     12:00     20:10
#
#    Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 44          73X        6N191            6N192              HH  000        -

# %%
df_frame52 = df_orig.query('KeyX == 2  & Key == 52 & Kdept == 10 & Karvl == 10')
df_frame52['FlightNumberArvl'] = df_frame52['Arvl Sta']
df_frame52['FlightNumbeR'] = df_frame52['Dept Sta'].apply(lambda x: x[1:8])
df_frame52['Dept Sta'] = df_frame52['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame52['Arvl Sta'] = df_frame52['Dept-Hora'].apply( lambda  x: x[4:7])
df_frame52['Arvl Day'] = df_frame52['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame52['Dept Day'] = df_frame52['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame52['Trilho'] = ''
df_frame52['Pax'] = df_frame52['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame52['Pax-Subfleet'] = df_frame52['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame52['Arvl-Hora'] = df_frame52['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
df_frame52['Dept-Hora'] = df_frame52['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame52 = df_frame52[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p23 = df_frame52
p23
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2175380656.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['FlightNumberArvl'] = df_frame52['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2175380656.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['FlightNumbeR'] = df_frame52['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2175380656.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Dept Sta'] = df_frame52['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2175380656.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Arvl Sta'] = df_frame52['Dept-Hora'].apply( lambda  x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2175380656.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Arvl Day'] = df_frame52['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2175380656.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Dept Day'] = df_frame52['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2175380656.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2175380656.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Pax'] = df_frame52['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2175380656.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Pax-Subfleet'] = df_frame52['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2175380656.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Arvl-Hora'] = df_frame52['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2175380656.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame52['Dept-Hora'] = df_frame52['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 6402      MIA      MDE  05/DEC/2023  05/DEC/2023     22:30     21:10
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 6402          76V       M38487            M3878              FF  000        -

# %%
df_frame53 = df_orig.query('KeyX == 2  & Key == 53 & Kdept == 10 & Karvl == 10')
df_frame53['FlightNumberArvl'] = df_frame53['Arvl Sta']
df_frame53['FlightNumbeR'] = df_frame53['Dept Sta'].apply(lambda x: x[1:8])
df_frame53['Dept Sta'] = df_frame53['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame53['Arvl Sta'] = df_frame53['Dept-Hora'].apply( lambda  x: x[4:7])
df_frame53['Arvl Day'] = df_frame53['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame53['Dept Day'] = df_frame53['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame53['Trilho'] = ''
df_frame53['Pax'] = df_frame53['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame53['Pax-Subfleet'] = df_frame53['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame53['Arvl-Hora'] = df_frame53['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
df_frame53['Dept-Hora'] = df_frame53['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame53 = df_frame53[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p24 = df_frame53
p24
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2794011763.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame53['FlightNumberArvl'] = df_frame53['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2794011763.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame53['FlightNumbeR'] = df_frame53['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2794011763.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame53['Dept Sta'] = df_frame53['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2794011763.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame53['Arvl Sta'] = df_frame53['Dept-Hora'].apply( lambda  x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2794011763.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame53['Arvl Day'] = df_frame53['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2794011763.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame53['Dept Day'] = df_frame53['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2794011763.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame53['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2794011763.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame53['Pax'] = df_frame53['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2794011763.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame53['Pax-Subfleet'] = df_frame53['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2794011763.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame53['Arvl-Hora'] = df_frame53['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2794011763.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame53['Dept-Hora'] = df_frame53['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 5992      MIA      TFS  14/NOV/2023  14/NOV/2023     13:10     11:10
# 5995      LUX      LUX  08/DEC/2023  08/DEC/2023     23:35     21:35
# 5996      LUX      UIO  16/DEC/2023  16/DEC/2023     07:05     04:40
# 5998      LUX      UIO  28/JAN/2023  28/JAN/2023     06:30     04:30
# 5999      LUX      UIO  04/FEB/2023  04/FEB/2023     06:00     04:00
# ...       ...      ...          ...          ...       ...       ...
# 6595      MIA      EZE  03/DEC/2023  03/DEC/2023     06:30     05:20
# 6596      MIA      EZE  10/DEC/2023  10/DEC/2023     06:50     03:50
# 6597      MIA      EZE  17/DEC/2023  17/DEC/2023     05:40     04:30
# 6598      MIA      EZE  24/DEC/2023  24/DEC/2023     05:00     03:50
# 6651      MIA      UIO  21/NOV/2023  21/NOV/2023     06:55     05:45
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 5992          74N       CV5791           CV5791              PH  000        -
# 5995          74N       CV6224           CV6225              FF  000        -
# 5996          74N       CV6224           CV6225              FP  000        -
# 5998          74Y       CV6224           CV6225              PH  000        -
# 5999          74N       CV6224           CV6225              FP  000        -
# ...           ...          ...              ...    ...      ...  ...      ...
# 6595          76V       UC1505           UC1505              FF  000        -
# 6596          76V       UC1505           UC1505              FF  000        -
# 6597          76V       UC1505           UC1505              FF  000        -
# 6598          76V       UC1505           UC1505              FF  000        -
# 6651          76V       UC1771           UC1771              FF  000        -
#
# [131 rows x 13 columns]

# %%
df_frame54 = df_orig.query('KeyX == 2  & Key == 54 & Kdept == 11 & Karvl == 10')
df_frame54['FlightNumberArvl'] = df_frame54['Arvl Sta']
df_frame54['FlightNumbeR'] = df_frame54['Dept Sta'].apply(lambda x: x[1:8])
df_frame54['Dept Sta'] = df_frame54['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame54['Arvl Sta'] = df_frame54['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame54['Arvl Day'] = df_frame54['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame54['Dept Day'] = df_frame54['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
df_frame54['Trilho'] = ''
df_frame54['Pax'] = df_frame54['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame54['Pax-Subfleet'] = df_frame54['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame54['Arvl-Hora'] = df_frame54['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
df_frame54['Dept-Hora'] = df_frame54['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame54 = df_frame54[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p25 = df_frame54
p25
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2512730221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame54['FlightNumberArvl'] = df_frame54['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2512730221.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame54['FlightNumbeR'] = df_frame54['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2512730221.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame54['Dept Sta'] = df_frame54['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2512730221.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame54['Arvl Sta'] = df_frame54['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2512730221.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame54['Arvl Day'] = df_frame54['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2512730221.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame54['Dept Day'] = df_frame54['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2512730221.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame54['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2512730221.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame54['Pax'] = df_frame54['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2512730221.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame54['Pax-Subfleet'] = df_frame54['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2512730221.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame54['Arvl-Hora'] = df_frame54['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2512730221.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame54['Dept-Hora'] = df_frame54['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta     Dept Day     Arvl Day Dept-Hora Arvl-Hora  \
# 5993      LUX      LUX  03/NOV/2023  03/NOV/2023     00:10     22:10
# 6007      LUX      LUX  05/DEC/2023  05/DEC/2023     09:30     18:00
# 6020      GIG      UIO  30/JAN/2023  30/JAN/2023     05:05     21:30
# 6022      GIG      UIO  20/FEB/2023  20/FEB/2023     17:25     21:30
# 6025      MEX      GRU  01/NOV/2023  01/NOV/2023     00:45     13:55
# 6028      LUX      LUX  19/NOV/2023  19/NOV/2023     00:00     22:30
# 6029      LUX      LUX  26/NOV/2023  26/NOV/2023     00:00     22:30
# 6030      LUX      LUX  03/DEC/2023  03/DEC/2023     00:00     22:30
# 6344      MIA      MAO  15/DEC/2023  15/DEC/2023     00:15     22:45
# 6359      MIA      UIO  05/NOV/2023  05/NOV/2023     00:15     23:00
# 6367      MIA      UIO  31/DEC/2023  31/DEC/2023     00:15     23:00
# 6396      MIA      BOG  18/DEC/2023  18/DEC/2023     00:35     21:45
# 6659      MIA      BOG  22/DEC/2023  22/DEC/2023     04:30     23:25
# 6663      YHM      SCL  13/NOV/2023  13/NOV/2023     00:00     20:00
#
#      Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho Svc Type  Pax Week-Day
# 5993          74Y       CV6224           CV6225              FF  000        -
# 6007          74Y       CV6227           CV6221              AA  000        -
# 6020          74N       CV6361           CV6361              FP  000        -
# 6022          74N       CV6361           CV6361              FP  000        -
# 6025          74Y       CV6652           CV6662              HA  000        -
# 6028          74N       CV6726           CV6727              FF  000        -
# 6029          74Y       CV6726           CV6727              FF  000        -
# 6030          74N       CV6726           CV6727              FF  000        -
# 6344          76V       M38431           M38440              FF  000        -
# 6359          76V       M38443           M38472              FF  000        -
# 6367          76V       M38443           M38472              FF  000        -
# 6396          76V       M38477           M38478              FF  000        -
# 6659          76Y       W80925           W80926              FF  000        -
# 6663          763       W81591           W81592              HH  000        -

# %%
df_frame56 = df_orig.query('KeyX == 2  & Key == 56 & Kdept == 7 & Karvl == 7')
df_frame56['FlightNumberArvl'] = df_frame56['Arvl Sta']
df_frame56['FlightNumbeR'] = df_frame56['Dept Sta'].apply(lambda x: x[1:8])
df_frame56['Dept Sta'] = df_frame56['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame56['Arvl Sta'] = df_frame56['Dept-Hora'].apply( lambda  x: x[4:7])
df_frame56['Arvl Day'] = df_frame56['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame56['Dept Day'] = df_frame56['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame56['Trilho'] = ''
df_frame56['Pax'] = df_frame56['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame56['Pax-Subfleet'] = df_frame56['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame56['Arvl-Hora'] = df_frame56['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame56['Dept-Hora'] = df_frame56['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame56 = df_frame56[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p26 = df_frame56
p26
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1981182282.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame56['FlightNumberArvl'] = df_frame56['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1981182282.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame56['FlightNumbeR'] = df_frame56['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1981182282.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame56['Dept Sta'] = df_frame56['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1981182282.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame56['Arvl Sta'] = df_frame56['Dept-Hora'].apply( lambda  x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1981182282.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame56['Arvl Day'] = df_frame56['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1981182282.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame56['Dept Day'] = df_frame56['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1981182282.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame56['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1981182282.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame56['Pax'] = df_frame56['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1981182282.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame56['Pax-Subfleet'] = df_frame56['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1981182282.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame56['Arvl-Hora'] = df_frame56['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1981182282.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame56['Dept-Hora'] = df_frame56['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#    Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 2       EZE      MIA  09/NOV/2023 á 23/NOV/2023  09/NOV/2023 á 23/NOV/2023
# 3       EZE      MIA  30/NOV/2023 á 21/DEC/2023  30/NOV/2023 á 21/DEC/2023
# 6       EZE      MIA  11/JAN/2023 á 22/FEB/2023  11/JAN/2023 á 22/FEB/2023
# 7       EZE      MIA  01/MAR/2023 á 08/MAR/2023  01/MAR/2023 á 08/MAR/2023
# 17      EZE      MIA  27/DEC/2023 á 03/JAN/2023  27/DEC/2023 á 03/JAN/2023
# 29      MIA      MIA  13/NOV/2023 á 20/NOV/2023  13/NOV/2023 á 20/NOV/2023
# 30      MIA      MIA  27/NOV/2023 á 18/DEC/2023  27/NOV/2023 á 18/DEC/2023
# 32      MIA      MIA  08/JAN/2023 á 19/MAR/2023  08/JAN/2023 á 19/MAR/2023
#
#    Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 2      13:30     09:25          76F        5X415            5X415
# 3      13:30     09:35          76F        5X415            5X415
# 6      13:00     09:35          76F        5X415            5X415
# 7      12:55     09:35          76F        5X415            5X415
# 17     06:00     04:45          76F        5X417            5X417
# 29     11:40     10:25          76F        5X444            5X445
# 30     14:25     10:25          76F        5X444            5X445
# 32     11:45     10:25          76F        5X444            5X445
#
#    Svc Type  Pax Week-Day
# 2        FF  000  0030000
# 3        FF  000  0030000
# 6        FF  000  0030000
# 7        FF  000  0030000
# 17       FF  000  0200000
# 29       FF  000  0000007
# 30       FF  000  0000007
# 32       FF  000  0000007

# %%
df_frame57 = df_orig.query('KeyX == 2  & Key == 57 & Kdept == 8 & Karvl == 7')
df_frame57['FlightNumberArvl'] = df_frame57['Arvl Sta']
df_frame57['FlightNumbeR'] = df_frame57['Dept Sta'].apply(lambda x: x[1:8])
df_frame57['Dept Sta'] = df_frame57['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame57['Arvl Sta'] = df_frame57['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame57['Arvl Day'] = df_frame57['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame57['Dept Day'] = df_frame57['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame57['Trilho'] = ''
df_frame57['Pax'] = df_frame57['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame57['Pax-Subfleet'] = df_frame57['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame57['Arvl-Hora'] = df_frame57['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame57['Dept-Hora'] = df_frame57['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame57 = df_frame57[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p27 = df_frame57
p27
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1479336491.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame57['FlightNumberArvl'] = df_frame57['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1479336491.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame57['FlightNumbeR'] = df_frame57['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1479336491.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame57['Dept Sta'] = df_frame57['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1479336491.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame57['Arvl Sta'] = df_frame57['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1479336491.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame57['Arvl Day'] = df_frame57['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1479336491.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame57['Dept Day'] = df_frame57['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1479336491.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame57['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1479336491.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame57['Pax'] = df_frame57['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1479336491.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame57['Pax-Subfleet'] = df_frame57['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1479336491.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame57['Arvl-Hora'] = df_frame57['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1479336491.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame57['Dept-Hora'] = df_frame57['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 15        EZE      MIA  07/NOV/2023 á 05/DEC/2023  07/NOV/2023 á 05/DEC/2023
# 16        EZE      MIA  12/DEC/2023 á 19/DEC/2023  12/DEC/2023 á 19/DEC/2023
# 22        EZE      MIA  06/FEB/2023 á 13/FEB/2023  06/FEB/2023 á 13/FEB/2023
# 6249      MIA      UIO  26/DEC/2023 á 02/JAN/2023  26/DEC/2023 á 02/JAN/2023
# 6253      MIA      MIA  18/JAN/2023 á 25/JAN/2023  18/JAN/2023 á 25/JAN/2023
# 6259      MIA      UIO  16/JAN/2023 á 30/JAN/2023  16/JAN/2023 á 30/JAN/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 15       03:05     22:45          76F        5X417            5X417
# 16       03:35     22:45          76F        5X417            5X417
# 22       04:30     22:45          76F        5X417            5X417
# 6249     06:30     11:00          744        K4537            K4536
# 6253     05:30     14:30          744        K4537            K4536
# 6259     06:00     16:00          744        K4539            K4538
#
#      Svc Type  Pax Week-Day
# 15         FF  000  1000000
# 16         FF  000  1000000
# 22         FF  000  1000000
# 6249       HH  000  1000000
# 6253       HH  000  0030000
# 6259       HH  000  1000000

# %%
df_frame58 = df_orig.query('KeyX == 2  & Key == 58 & Kdept == 7 & Karvl == 7')
df_frame58['FlightNumberArvl'] = df_frame58['Arvl Sta']
df_frame58['FlightNumbeR'] = df_frame58['Dept Sta'].apply(lambda x: x[1:8])
df_frame58['Dept Sta'] = df_frame58['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame58['Arvl Sta'] = df_frame58['Dept-Hora'].apply( lambda  x: x[4:8])
df_frame58['Arvl Day'] = df_frame58['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame58['Dept Day'] = df_frame58['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame58['Trilho'] = ''
df_frame58['Pax'] = df_frame58['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame58['Pax-Subfleet'] = df_frame58['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame58['Arvl-Hora'] = df_frame58['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame58['Dept-Hora'] = df_frame58['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame58 = df_frame58[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p28 = df_frame58
p28
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2972752034.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame58['FlightNumberArvl'] = df_frame58['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2972752034.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame58['FlightNumbeR'] = df_frame58['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2972752034.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame58['Dept Sta'] = df_frame58['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2972752034.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame58['Arvl Sta'] = df_frame58['Dept-Hora'].apply( lambda  x: x[4:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2972752034.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame58['Arvl Day'] = df_frame58['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2972752034.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame58['Dept Day'] = df_frame58['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2972752034.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame58['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2972752034.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame58['Pax'] = df_frame58['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2972752034.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame58['Pax-Subfleet'] = df_frame58['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2972752034.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame58['Arvl-Hora'] = df_frame58['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2972752034.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame58['Dept-Hora'] = df_frame58['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 33        MIA      SCL  04/NOV/2023 á 17/MAR/2023  04/NOV/2023 á 17/MAR/2023
# 34        MIA      MIA  04/NOV/2023 á 17/MAR/2023  04/NOV/2023 á 17/MAR/2023
# 35        MIA      SCL  03/NOV/2023 á 23/MAR/2023  03/NOV/2023 á 23/MAR/2023
# 37        MIA      UIO  05/NOV/2023 á 25/MAR/2023  05/NOV/2023 á 25/MAR/2023
# 38        MIA      SCL  05/NOV/2023 á 25/MAR/2023  05/NOV/2023 á 25/MAR/2023
# 39        MIA      LIM  02/NOV/2023 á 22/MAR/2023  02/NOV/2023 á 22/MAR/2023
# 43        MIA      BOG  31/OCT/2023 á 20/MAR/2023  31/OCT/2023 á 20/MAR/2023
# 6287      MIA      MDE  18/JAN/2023 á 22/MAR/2023  18/JAN/2023 á 22/MAR/2023
# 6305      MIA      MDE  04/NOV/2023 á 11/NOV/2023  04/NOV/2023 á 11/NOV/2023
# 6306      MIA      MDE  20/JAN/2023 á 24/MAR/2023  20/JAN/2023 á 24/MAR/2023
# 6517      MIA      BOG  07/FEB/2023 á 21/MAR/2023  07/FEB/2023 á 21/MAR/2023
# 6521      MIA      SCL  16/NOV/2023 á 23/NOV/2023  16/NOV/2023 á 23/NOV/2023
# 6528      MIA      BOG  21/JAN/2023 á 28/JAN/2023  21/JAN/2023 á 28/JAN/2023
# 6529      MIA      BOG  01/FEB/2023 á 22/MAR/2023  01/FEB/2023 á 22/MAR/2023
# 6531      CWB      BOG  06/NOV/2023 á 27/NOV/2023  06/NOV/2023 á 27/NOV/2023
# 6544      CWB      BOG  08/JAN/2023 á 12/JAN/2023  08/JAN/2023 á 12/JAN/2023
# 6546      CWB      BOG  19/JAN/2023 á 29/JAN/2023  19/JAN/2023 á 29/JAN/2023
# 6549      CWB      BOG  02/FEB/2023 á 26/MAR/2023  02/FEB/2023 á 26/MAR/2023
# 6560      EZE      BOG  18/JAN/2023 á 25/JAN/2023  18/JAN/2023 á 25/JAN/2023
# 6623      MIA      SCL  14/NOV/2023 á 21/NOV/2023  14/NOV/2023 á 21/NOV/2023
# 6643      MIA      SCL  18/JAN/2023 á 22/MAR/2023  18/JAN/2023 á 22/MAR/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 33       19:00     15:50          744       5Y0021           5Y0022
# 34       19:55     16:55          74H       5Y0031           5Y0032
# 35       21:35     19:35          74H       5Y0045           5Y0046
# 37       16:10     14:10          744       5Y0057           5Y0058
# 38       06:35     04:35          744       5Y0061           5Y0062
# 39       16:10     14:10          744       5Y0063           5Y0064
# 43       13:55     11:55          744       5Y9533           5Y9534
# 6287     03:00     01:30          76V       L71819           L71819
# 6305     21:00     19:40          76V       L72841           L72841
# 6306     21:00     19:40          76V       L72841           L72841
# 6517     19:50     18:20          332       QT4051           QT4052
# 6521     21:15     19:45          332       QT4053           QT4054
# 6528     17:45     16:15          332       QT4053           QT4054
# 6529     19:50     18:20          332       QT4053           QT4054
# 6531     23:00     21:30          332       QT4055           QT4060
# 6544     23:45     22:15          332       QT4055           QT4060
# 6546     23:45     22:15          332       QT4055           QT4060
# 6549     18:20     16:40          332       QT4060           QT4060
# 6560     21:15     19:45          332       QT4099           QT4054
# 6623     15:20     14:10          76V       UC1527           UC1527
# 6643     11:55     09:55          76V       UC1731           UC1731
#
#      Svc Type  Pax Week-Day
# 33         FF  000  0000500
# 34         FF  000  0000500
# 35         FF  000  0004000
# 37         FF  000  0000060
# 38         FF  000  0000060
# 39         FF  000  0030000
# 43         FF  000  1000000
# 6287       FF  000  0030000
# 6305       FF  000  0000500
# 6306       FF  000  0000500
# 6517       FF  000  0200000
# 6521       FF  000  0030000
# 6528       FF  000  0000060
# 6529       FF  000  0030000
# 6531       FF  000  0000007
# 6544       FF  000  0004007
# 6546       FF  000  0004007
# 6549       FF  000  0004007
# 6560       FF  000  0030000
# 6623       FF  000  1000000
# 6643       FF  000  0030000

# %%
df_frame59 = df_orig.query('KeyX == 2  & Key == 59 & Kdept == 10 & Karvl == 7')
df_frame59['FlightNumberArvl'] = df_frame59['Arvl Sta']
df_frame59['FlightNumbeR'] = df_frame59['Dept Sta'].apply(lambda x: x[1:8])
df_frame59['Dept Sta'] = df_frame59['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame59['Arvl Sta'] = df_frame59['Dept-Hora'].apply( lambda  x: x[4:7])
df_frame59['Arvl Day'] = df_frame59['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame59['Dept Day'] = df_frame59['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame59['Trilho'] = ''
df_frame59['Pax'] = df_frame59['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame59['Pax-Subfleet'] = df_frame59['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame59['Arvl-Hora'] = df_frame59['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame59['Dept-Hora'] = df_frame59['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame59 = df_frame59[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p29 = df_frame59
p29
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1514417269.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['FlightNumberArvl'] = df_frame59['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1514417269.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['FlightNumbeR'] = df_frame59['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1514417269.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Dept Sta'] = df_frame59['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1514417269.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Arvl Sta'] = df_frame59['Dept-Hora'].apply( lambda  x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1514417269.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Arvl Day'] = df_frame59['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1514417269.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Dept Day'] = df_frame59['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1514417269.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1514417269.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Pax'] = df_frame59['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1514417269.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Pax-Subfleet'] = df_frame59['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1514417269.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Arvl-Hora'] = df_frame59['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1514417269.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Dept-Hora'] = df_frame59['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#    Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 0       MIA      SCL  14/MAR/2023 á 21/MAR/2023  14/MAR/2023 á 21/MAR/2023
# 8       EZE      BOG  15/MAR/2023 á 22/MAR/2023  15/MAR/2023 á 22/MAR/2023
# 10      MIA      SCL  06/NOV/2023 á 18/DEC/2023  06/NOV/2023 á 18/DEC/2023
# 11      MIA      SCL  26/DEC/2023 á 02/JAN/2023  26/DEC/2023 á 02/JAN/2023
# 12      MIA      SCL  08/JAN/2023 á 05/MAR/2023  08/JAN/2023 á 05/MAR/2023
# 13      MIA      SCL  12/MAR/2023 á 19/MAR/2023  12/MAR/2023 á 19/MAR/2023
#
#    Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 0      22:10     19:50          76F        5X414            5X414
# 8      10:50     09:25          76F        5X415            5X415
# 10     19:20     17:30          76F        5X416            5X416
# 11     18:10     16:50          76F        5X416            5X416
# 12     19:20     17:30          76F        5X416            5X416
# 13     22:05     16:45          76F        5X416            5X416
#
#    Svc Type  Pax Week-Day
# 0        FF  000  0200000
# 8        FF  000  0030000
# 10       FF  000  0000007
# 11       FF  000  1000000
# 12       FF  000  0000007
# 13       FF  000  0000007

# %%
df_frame59 = df_orig.query('KeyX == 2  & Key == 59 & Kdept == 8 & Karvl == 7')
df_frame59['FlightNumberArvl'] = df_frame59['Arvl Sta']
df_frame59['FlightNumbeR'] = df_frame59['Dept Sta'].apply(lambda x: x[1:8])
df_frame59['Dept Sta'] = df_frame59['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame59['Arvl Sta'] = df_frame59['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame59['Arvl Day'] = df_frame59['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame59['Dept Day'] = df_frame59['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame59['Trilho'] = ''
df_frame59['Pax'] = df_frame59['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame59['Pax-Subfleet'] = df_frame59['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame59['Arvl-Hora'] = df_frame59['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame59['Dept-Hora'] = df_frame59['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame59 = df_frame59[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p30 = df_frame59
p30
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2864576164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['FlightNumberArvl'] = df_frame59['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2864576164.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['FlightNumbeR'] = df_frame59['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2864576164.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Dept Sta'] = df_frame59['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2864576164.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Arvl Sta'] = df_frame59['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2864576164.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Arvl Day'] = df_frame59['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2864576164.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Dept Day'] = df_frame59['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2864576164.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2864576164.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Pax'] = df_frame59['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2864576164.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Pax-Subfleet'] = df_frame59['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2864576164.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Arvl-Hora'] = df_frame59['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2864576164.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame59['Dept-Hora'] = df_frame59['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 36        MIA      SCL  30/OCT/2023 á 19/MAR/2023  30/OCT/2023 á 19/MAR/2023
# 40        MIA      BOG  03/NOV/2023 á 23/MAR/2023  03/NOV/2023 á 23/MAR/2023
# 6310      MIA      BOG  21/JAN/2023 á 25/MAR/2023  21/JAN/2023 á 25/MAR/2023
# 6314      MIA      BOG  31/OCT/2023 á 07/NOV/2023  31/OCT/2023 á 07/NOV/2023
# 6537      CWB      BOG  04/DEC/2023 á 11/DEC/2023  04/DEC/2023 á 11/DEC/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 36       01:20     23:20          744       5Y0055           5Y0056
# 40       00:10     22:10          744       5Y0075           5Y0076
# 6310     00:50     23:40          76V       L72861           L72861
# 6314     00:40     23:30          76V       L72893           L72893
# 6537     00:15     22:35          332       QT4055           QT4060
#
#      Svc Type  Pax Week-Day
# 36         FF  000  0000007
# 40         FF  000  0004000
# 6310       FF  000  0000060
# 6314       FF  000  1000000
# 6537       FF  000  0000007

# %%
df_frame60 = df_orig.query('KeyX == 2  & Key == 60 & Kdept == 11 & Karvl == 7')
df_frame60['FlightNumberArvl'] = df_frame60['Arvl Sta']
df_frame60['FlightNumbeR'] = df_frame60['Dept Sta'].apply(lambda x: x[1:8])
df_frame60['Dept Sta'] = df_frame60['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame60['Arvl Sta'] = df_frame60['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame60['Arvl Day'] = df_frame60['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame60['Dept Day'] = df_frame60['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame60['Trilho'] = ''
df_frame60['Pax'] = df_frame60['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame60['Pax-Subfleet'] = df_frame60['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame60['Arvl-Hora'] = df_frame60['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame60['Dept-Hora'] = df_frame60['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame60 = df_frame60[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p31 = df_frame60
p31
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\169305289.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['FlightNumberArvl'] = df_frame60['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\169305289.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['FlightNumbeR'] = df_frame60['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\169305289.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Dept Sta'] = df_frame60['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\169305289.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Arvl Sta'] = df_frame60['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\169305289.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Arvl Day'] = df_frame60['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\169305289.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Dept Day'] = df_frame60['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\169305289.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\169305289.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Pax'] = df_frame60['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\169305289.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Pax-Subfleet'] = df_frame60['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\169305289.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Arvl-Hora'] = df_frame60['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\169305289.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Dept-Hora'] = df_frame60['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#    Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 26      EZE      BOG  13/MAR/2023 á 20/MAR/2023  13/MAR/2023 á 20/MAR/2023
#
#    Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 26     00:10     21:40          76F        5X417            5X417
#
#    Svc Type  Pax Week-Day
# 26       FF  000  1000000

# %%
df_frame60 = df_orig.query('KeyX == 2  & Key == 60 & Kdept == 7 & Karvl == 7')
df_frame60['FlightNumberArvl'] = df_frame60['Arvl Sta']
df_frame60['FlightNumbeR'] = df_frame60['Dept Sta'].apply(lambda x: x[1:8])
df_frame60['Dept Sta'] = df_frame60['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame60['Arvl Sta'] = df_frame60['Dept-Hora'].apply( lambda  x: x[4:8])
df_frame60['Arvl Day'] = df_frame60['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame60['Dept Day'] = df_frame60['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame60['Trilho'] = ''
df_frame60['Pax'] = df_frame60['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame60['Pax-Subfleet'] = df_frame60['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame60['Arvl-Hora'] = df_frame60['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame60['Dept-Hora'] = df_frame60['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame60 = df_frame60[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p32 = df_frame60
p32
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3445584.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['FlightNumberArvl'] = df_frame60['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3445584.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['FlightNumbeR'] = df_frame60['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3445584.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Dept Sta'] = df_frame60['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3445584.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Arvl Sta'] = df_frame60['Dept-Hora'].apply( lambda  x: x[4:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3445584.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Arvl Day'] = df_frame60['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3445584.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Dept Day'] = df_frame60['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3445584.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3445584.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Pax'] = df_frame60['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3445584.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Pax-Subfleet'] = df_frame60['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3445584.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Arvl-Hora'] = df_frame60['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3445584.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame60['Dept-Hora'] = df_frame60['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 6237      EZE      FRA  31/OCT/2023 á 13/MAR/2023  31/OCT/2023 á 13/MAR/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 6237     19:20     17:20          77X      GEC8267          GEC8267
#
#      Svc Type  Pax Week-Day
# 6237       FF  000  1000000

# %%
df_frame61 = df_orig.query('KeyX == 2  & Key == 61 & Kdept == 10 & Karvl == 7')
df_frame61['FlightNumberArvl'] = df_frame61['Arvl Sta']
df_frame61['FlightNumbeR'] = df_frame61['Dept Sta'].apply(lambda x: x[1:8])
df_frame61['Dept Sta'] = df_frame61['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame61['Arvl Sta'] = df_frame61['Dept-Hora'].apply( lambda  x: x[4:7])
df_frame61['Arvl Day'] = df_frame61['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame61['Dept Day'] = df_frame61['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame61['Trilho'] = ''
df_frame61['Pax'] = df_frame61['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame61['Pax-Subfleet'] = df_frame61['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame61['Arvl-Hora'] = df_frame61['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
df_frame61['Dept-Hora'] = df_frame61['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame61 = df_frame61[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p33 = df_frame61
p33
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\696059575.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['FlightNumberArvl'] = df_frame61['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\696059575.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['FlightNumbeR'] = df_frame61['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\696059575.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Dept Sta'] = df_frame61['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\696059575.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Arvl Sta'] = df_frame61['Dept-Hora'].apply( lambda  x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\696059575.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Arvl Day'] = df_frame61['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\696059575.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Dept Day'] = df_frame61['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\696059575.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\696059575.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Pax'] = df_frame61['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\696059575.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Pax-Subfleet'] = df_frame61['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\696059575.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Arvl-Hora'] = df_frame61['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\696059575.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Dept-Hora'] = df_frame61['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 6312      MIA      UIO  13/NOV/2023 á 20/NOV/2023  13/NOV/2023 á 20/NOV/2023
# 6313      MIA      UIO  08/JAN/2023 á 19/MAR/2023  08/JAN/2023 á 19/MAR/2023
# 6315      MIA      AGT  05/DEC/2023 á 12/DEC/2023  05/DEC/2023 á 12/DEC/2023
# 6317      MIA      AGT  23/JAN/2023 á 20/MAR/2023  23/JAN/2023 á 20/MAR/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 6312     21:45     20:25          76V       L72871           L72871
# 6313     21:45     20:25          76V       L72871           L72871
# 6315     10:25     09:15          76V       L72897           L72897
# 6317     10:25     09:15          76V       L72897           L72897
#
#      Svc Type  Pax Week-Day
# 6312       FF  000  0000007
# 6313       FF  000  0000007
# 6315       FF  000  1000000
# 6317       FF  000  1000000

# %%
df_frame61 = df_orig.query('KeyX == 2  & Key == 61 & Kdept == 7 & Karvl == 10')
df_frame61['FlightNumberArvl'] = df_frame61['Arvl Sta']
df_frame61['FlightNumbeR'] = df_frame61['Dept Sta'].apply(lambda x: x[1:8])
df_frame61['Dept Sta'] = df_frame61['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame61['Arvl Sta'] = df_frame61['Dept-Hora'].apply( lambda  x: x[4:7])
df_frame61['Arvl Day'] = df_frame61['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame61['Dept Day'] = df_frame61['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame61['Trilho'] = ''
df_frame61['Pax'] = df_frame61['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame61['Pax-Subfleet'] = df_frame61['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame61['Arvl-Hora'] = df_frame61['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
df_frame61['Dept-Hora'] = df_frame61['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame60 = df_frame61[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p34 = df_frame61
p34
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2553065986.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['FlightNumberArvl'] = df_frame61['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2553065986.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['FlightNumbeR'] = df_frame61['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2553065986.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Dept Sta'] = df_frame61['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2553065986.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Arvl Sta'] = df_frame61['Dept-Hora'].apply( lambda  x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2553065986.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Arvl Day'] = df_frame61['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2553065986.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Dept Day'] = df_frame61['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2553065986.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2553065986.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Pax'] = df_frame61['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2553065986.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Pax-Subfleet'] = df_frame61['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2553065986.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Arvl-Hora'] = df_frame61['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2553065986.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame61['Dept-Hora'] = df_frame61['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day Week-Day Pax-Subfleet  \
# 6303      BOG      UIO  19/JAN/2023 á 23/MAR/2023  0004000          76V
# 6388      MIA      GRU  05/DEC/2023 á 12/DEC/2023  1000000          76V
# 6391      MIA      GRU  23/JAN/2023 á 20/MAR/2023  1000000          76V
# 6498      DOH      SCL  03/NOV/2023 á 22/DEC/2023  0004000          77X
# 6499      DOH      SCL  05/JAN/2023 á 23/MAR/2023  0004000          77X
# 6503      DOH      SCL  20/NOV/2023 á 25/DEC/2023  0000007          77X
# 6504      DOH      SCL  08/JAN/2023 á 19/MAR/2023  0000007          77X
# 6569      MIA      SCL  17/JAN/2023 á 21/MAR/2023  0200000          76V
# 6579      MIA      SCL  18/JAN/2023 á 22/MAR/2023  0030000          76V
# 6591      MIA      SCL  19/JAN/2023 á 23/MAR/2023  0004000          76V
# 6602      MIA      SCL  13/NOV/2023 á 20/NOV/2023  0000007          76V
# 6607      MIA      SCL  08/JAN/2023 á 19/MAR/2023  0000007          76V
# 6609      MIA      SCL  07/NOV/2023 á 14/NOV/2023  1000000          76V
# 6620      MIA      SCL  23/JAN/2023 á 20/MAR/2023  1000000          76V
#
#      Arvl-Hora Dept-Hora Svc Type FlightNumbeR FlightNumberArvl  \
# 6303     06:50     08:00       FF       L72831           L72831
# 6388     19:00     20:10       FF       M38473           M38473
# 6391     19:00     20:10       FF       M38473           M38473
# 6498     19:40     21:30       FF       QR8133           QR8133
# 6499     19:40     21:45       FF       QR8133           QR8133
# 6503     21:10     22:55       FF       QR8147           QR8147
# 6504     21:10     22:55       FF       QR8147           QR8147
# 6569     05:30     06:40       FF       UC1501           UC1501
# 6579     04:40     05:50       FF       UC1502           UC1502
# 6591     06:40     07:50       FF       UC1503           UC1503
# 6602     04:30     05:40       FF       UC1506           UC1506
# 6607     04:30     05:40       FF       UC1506           UC1506
# 6609     04:30     05:40       FF       UC1507           UC1507
# 6620     04:30     05:40       FF       UC1507           UC1507
#
#                                              Concatenar  Key  KeyX  Kdept  \
# 6303  L72831HL7283119JAN23MAR000400000076V00076VBOGM...   61     2      7
# 6388  M38473HM3847305DEC12DEC100000000076V00076VMIAC...   61     2      7
# 6391  M38473HM3847323JAN20MAR100000000076V00076VMIAC...   61     2      7
# 6498  QR8133HQR813303NOV22DEC000400000077X00077XDOHL...   61     2      7
# 6499  QR8133HQR813305JAN23MAR000400000077X00077XDOHL...   61     2      7
# 6503  QR8147HQR814720NOV25DEC000000700077X00077XDOHL...   61     2      7
# 6504  QR8147HQR814708JAN19MAR000000700077X00077XDOHL...   61     2      7
# 6569  UC1501HUC150117JAN21MAR020000000076V00076VMIAS...   61     2      7
# 6579  UC1502HUC150218JAN22MAR003000000076V00076VMIAS...   61     2      7
# 6591  UC1503HUC150319JAN23MAR000400000076V00076VMIAS...   61     2      7
# 6602  UC1506HUC150613NOV20NOV000000700076V00076VMIAS...   61     2      7
# 6607  UC1506HUC150608JAN19MAR000000700076V00076VMIAS...   61     2      7
# 6609  UC1507HUC150707NOV14NOV100000000076V00076VMIAS...   61     2      7
# 6620  UC1507HUC150723JAN20MAR100000000076V00076VMIAS...   61     2      7
#
#       Karvl                   Arvl Day Trilho  Pax
# 6303     10  19/JAN/2023 á 23/MAR/2023         000
# 6388     10  05/DEC/2023 á 12/DEC/2023         000
# 6391     10  23/JAN/2023 á 20/MAR/2023         000
# 6498     10  03/NOV/2023 á 22/DEC/2023         000
# 6499     10  05/JAN/2023 á 23/MAR/2023         000
# 6503     10  20/NOV/2023 á 25/DEC/2023         000
# 6504     10  08/JAN/2023 á 19/MAR/2023         000
# 6569     10  17/JAN/2023 á 21/MAR/2023         000
# 6579     10  18/JAN/2023 á 22/MAR/2023         000
# 6591     10  19/JAN/2023 á 23/MAR/2023         000
# 6602     10  13/NOV/2023 á 20/NOV/2023         000
# 6607     10  08/JAN/2023 á 19/MAR/2023         000
# 6609     10  07/NOV/2023 á 14/NOV/2023         000
# 6620     10  23/JAN/2023 á 20/MAR/2023         000

# %%
df_frame62 = df_orig.query('KeyX == 2  & Key == 62 & Kdept == 10 & Karvl == 10')
df_frame62['FlightNumberArvl'] = df_frame62['Arvl Sta']
df_frame62['FlightNumbeR'] = df_frame62['Dept Sta'].apply(lambda x: x[1:8])
df_frame62['Dept Sta'] = df_frame62['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame62['Arvl Sta'] = df_frame62['Dept-Hora'].apply( lambda  x: x[4:7])
df_frame62['Arvl Day'] = df_frame62['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame62['Dept Day'] = df_frame62['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame62['Trilho'] = ''
df_frame62['Pax'] = df_frame62['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame62['Pax-Subfleet'] = df_frame62['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame62['Arvl-Hora'] = df_frame62['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
df_frame62['Dept-Hora'] = df_frame62['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame62 = df_frame62[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p35 = df_frame62
p35
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1767939522.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame62['FlightNumberArvl'] = df_frame62['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1767939522.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame62['FlightNumbeR'] = df_frame62['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1767939522.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame62['Dept Sta'] = df_frame62['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1767939522.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame62['Arvl Sta'] = df_frame62['Dept-Hora'].apply( lambda  x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1767939522.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame62['Arvl Day'] = df_frame62['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1767939522.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame62['Dept Day'] = df_frame62['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1767939522.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame62['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1767939522.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame62['Pax'] = df_frame62['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1767939522.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame62['Pax-Subfleet'] = df_frame62['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1767939522.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame62['Arvl-Hora'] = df_frame62['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1767939522.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame62['Dept-Hora'] = df_frame62['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 6260      MIA      SCL  30/OCT/2023 á 18/DEC/2023  30/OCT/2023 á 18/DEC/2023
# 6261      MIA      SCL  03/NOV/2023 á 23/MAR/2023  03/NOV/2023 á 23/MAR/2023
# 6262      MIA      SCL  25/DEC/2023 á 19/MAR/2023  25/DEC/2023 á 19/MAR/2023
# 6263      MIA      SCL  07/JAN/2023 á 14/JAN/2023  07/JAN/2023 á 14/JAN/2023
# 6264      MIA      SCL  04/FEB/2023 á 18/MAR/2023  04/FEB/2023 á 18/MAR/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 6260     21:35     19:35          77X        KE273            KE274
# 6261     20:45     18:30          77X        KE273            KE274
# 6262     21:35     19:35          77X        KE273            KE274
# 6263     21:35     19:35          77X        KE273            KE274
# 6264     21:35     19:35          77X        KE273            KE274
#
#      Svc Type  Pax Week-Day
# 6260       FF  000  0000067
# 6261       FF  000  0004000
# 6262       FF  000  0000007
# 6263       FF  000  0000060
# 6264       FF  000  0000060

# %%
df_frame64 = df_orig.query('KeyX == 2  & Key == 64 & Kdept == 10 & Karvl == 10')
df_frame64['FlightNumberArvl'] = df_frame64['Arvl Sta']
df_frame64['FlightNumbeR'] = df_frame64['Dept Sta'].apply(lambda x: x[1:8])
df_frame64['Dept Sta'] = df_frame64['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame64['Arvl Sta'] = df_frame64['Dept-Hora'].apply( lambda  x: x[4:7])
df_frame64['Arvl Day'] = df_frame64['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame64['Dept Day'] = df_frame64['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame64['Trilho'] = ''
df_frame64['Pax'] = df_frame64['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame64['Pax-Subfleet'] = df_frame64['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame64['Arvl-Hora'] = df_frame64['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
df_frame64['Dept-Hora'] = df_frame64['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame64 = df_frame64[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p36 = df_frame64
p36
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1048116526.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['FlightNumberArvl'] = df_frame64['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1048116526.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['FlightNumbeR'] = df_frame64['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1048116526.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Dept Sta'] = df_frame64['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1048116526.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Arvl Sta'] = df_frame64['Dept-Hora'].apply( lambda  x: x[4:7])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1048116526.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Arvl Day'] = df_frame64['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1048116526.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Dept Day'] = df_frame64['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1048116526.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1048116526.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Pax'] = df_frame64['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1048116526.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Pax-Subfleet'] = df_frame64['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1048116526.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Arvl-Hora'] = df_frame64['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1048116526.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Dept-Hora'] = df_frame64['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 5994      LUX      LUX  11/NOV/2023 á 02/DEC/2023  11/NOV/2023 á 02/DEC/2023
# 5997      LUX      LUX  13/JAN/2023 á 20/JAN/2023  13/JAN/2023 á 20/JAN/2023
# 6002      LUX      LUX  24/FEB/2023 á 24/MAR/2023  24/FEB/2023 á 24/MAR/2023
# 6004      LUX      LUX  31/OCT/2023 á 07/NOV/2023  31/OCT/2023 á 07/NOV/2023
# 6006      LUX      LUX  21/NOV/2023 á 28/NOV/2023  21/NOV/2023 á 28/NOV/2023
# ...       ...      ...                        ...                        ...
# 6488      AMS      SCL  12/NOV/2023 á 24/DEC/2023  12/NOV/2023 á 24/DEC/2023
# 6490      AMS      SCL  14/JAN/2023 á 25/MAR/2023  14/JAN/2023 á 25/MAR/2023
# 6491      AMS      LIM  30/OCT/2023 á 06/NOV/2023  30/OCT/2023 á 06/NOV/2023
# 6492      AMS      LIM  20/NOV/2023 á 25/DEC/2023  20/NOV/2023 á 25/DEC/2023
# 6494      AMS      LIM  08/JAN/2023 á 19/MAR/2023  08/JAN/2023 á 19/MAR/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 5994     07:05     04:40          74Y       CV6224           CV6225
# 5997     07:05     04:40          74Y       CV6224           CV6225
# 6002     07:05     04:40          74Y       CV6224           CV6225
# 6004     02:40     00:40          74Y       CV6227           CV6221
# 6006     02:40     00:40          74Y       CV6227           CV6221
# ...        ...       ...          ...          ...              ...    ...
# 6488     08:30     05:45          74Y       MP7551           MP7552
# 6490     08:30     05:45          74Y       MP7551           MP7552
# 6491     08:30     06:30          74Y       MP7761           MP7762
# 6492     08:30     06:30          74Y       MP7761           MP7762
# 6494     08:30     06:30          74Y       MP7761           MP7762
#
#      Svc Type  Pax Week-Day
# 5994       FF  000  0000500
# 5997       FF  000  0000500
# 6002       FF  000  0000500
# 6004       AA  000  1000000
# 6006       AA  000  1000000
# ...       ...  ...      ...
# 6488       FF  000  0000060
# 6490       FF  000  0000060
# 6491       FF  000  0000007
# 6492       FF  000  0000007
# 6494       FF  000  0000007
#
# [72 rows x 13 columns]

# %%
df_frame64 = df_orig.query('KeyX == 2  & Key == 64 & Kdept == 11 & Karvl == 7')
df_frame64['FlightNumberArvl'] = df_frame64['Arvl Sta']
df_frame64['FlightNumbeR'] = df_frame64['Dept Sta'].apply(lambda x: x[1:8])
df_frame64['Dept Sta'] = df_frame64['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame64['Arvl Sta'] = df_frame64['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame64['Arvl Day'] = df_frame64['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame64['Dept Day'] = df_frame64['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame64['Trilho'] = ''
df_frame64['Pax'] = df_frame64['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame64['Pax-Subfleet'] = df_frame64['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame64['Arvl-Hora'] = df_frame64['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7] )
df_frame64['Dept-Hora'] = df_frame64['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame64 = df_frame64[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p37 = df_frame64
p37
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2852691533.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['FlightNumberArvl'] = df_frame64['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2852691533.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['FlightNumbeR'] = df_frame64['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2852691533.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Dept Sta'] = df_frame64['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2852691533.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Arvl Sta'] = df_frame64['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2852691533.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Arvl Day'] = df_frame64['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2852691533.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Dept Day'] = df_frame64['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2852691533.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2852691533.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Pax'] = df_frame64['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2852691533.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Pax-Subfleet'] = df_frame64['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2852691533.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Arvl-Hora'] = df_frame64['Arvl-Hora'].apply( lambda x: x[3:5] + ':' + x[5:7] )
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\2852691533.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame64['Dept-Hora'] = df_frame64['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 6232      FRA      MVD  02/NOV/2023 á 21/DEC/2023  02/NOV/2023 á 21/DEC/2023
# 6233      FRA      MVD  04/NOV/2023 á 23/DEC/2023  04/NOV/2023 á 23/DEC/2023
# 6234      FRA      MVD  04/JAN/2023 á 22/MAR/2023  04/JAN/2023 á 22/MAR/2023
# 6235      FRA      MVD  13/JAN/2023 á 10/MAR/2023  13/JAN/2023 á 10/MAR/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 6232     04:40     23:40          77X      GEC8264          GEC8264
# 6233     04:30     23:25          77X      GEC8264          GEC8264
# 6234     04:40     23:40          77X      GEC8264          GEC8264
# 6235     04:30     23:25          77X      GEC8264          GEC8264
#
#      Svc Type  Pax Week-Day
# 6232       FF  000  0030000
# 6233       FF  000  0000500
# 6234       FF  000  0030000
# 6235       FF  000  0000500

# %%
df_frame65 = df_orig.query('KeyX == 2  & Key == 65 & Kdept == 11 & Karvl == 10')
df_frame65['FlightNumberArvl'] = df_frame65['Arvl Sta']
df_frame65['FlightNumbeR'] = df_frame65['Dept Sta'].apply(lambda x: x[1:8])
df_frame65['Dept Sta'] = df_frame65['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame65['Arvl Sta'] = df_frame65['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame65['Arvl Day'] = df_frame65['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame65['Dept Day'] = df_frame65['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame65['Trilho'] = ''
df_frame65['Pax'] = df_frame65['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame65['Pax-Subfleet'] = df_frame65['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame65['Arvl-Hora'] = df_frame65['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10] )
df_frame65['Dept-Hora'] = df_frame65['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame65 = df_frame65[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p38 = df_frame65
p38
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3688110948.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame65['FlightNumberArvl'] = df_frame65['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3688110948.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame65['FlightNumbeR'] = df_frame65['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3688110948.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame65['Dept Sta'] = df_frame65['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3688110948.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame65['Arvl Sta'] = df_frame65['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3688110948.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame65['Arvl Day'] = df_frame65['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3688110948.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame65['Dept Day'] = df_frame65['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3688110948.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame65['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3688110948.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame65['Pax'] = df_frame65['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3688110948.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame65['Pax-Subfleet'] = df_frame65['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3688110948.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame65['Arvl-Hora'] = df_frame65['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10] )
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\3688110948.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame65['Dept-Hora'] = df_frame65['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 6027      LUX      LUX  05/NOV/2023 á 12/NOV/2023  05/NOV/2023 á 12/NOV/2023
# 6031      LUX      LUX  10/DEC/2023 á 11/FEB/2023  10/DEC/2023 á 11/FEB/2023
# 6033      LUX      LUX  25/FEB/2023 á 18/MAR/2023  25/FEB/2023 á 18/MAR/2023
# 6052      MEM      MEM  09/JAN/2023 á 30/JAN/2023  09/JAN/2023 á 30/JAN/2023
# 6349      MIA      MAO  19/JAN/2023 á 23/MAR/2023  19/JAN/2023 á 23/MAR/2023
# 6370      MIA      UIO  21/JAN/2023 á 25/MAR/2023  21/JAN/2023 á 25/MAR/2023
# 6393      MIA      UIO  13/NOV/2023 á 20/NOV/2023  13/NOV/2023 á 20/NOV/2023
# 6397      MIA      UIO  25/DEC/2023 á 19/MAR/2023  25/DEC/2023 á 19/MAR/2023
# 6658      YVR      BOG  30/OCT/2023 á 21/DEC/2023  30/OCT/2023 á 21/DEC/2023
# 6660      YVR      BOG  25/DEC/2023 á 23/MAR/2023  25/DEC/2023 á 23/MAR/2023
# 6661      YVR      BOG  06/JAN/2023 á 24/MAR/2023  06/JAN/2023 á 24/MAR/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 6027     00:00     22:30          74Y       CV6726           CV6727
# 6031     00:00     22:30          74Y       CV6726           CV6727
# 6033     00:00     22:30          74Y       CV6726           CV6727
# 6052     17:45     14:00          76F       FX0042           FX0041
# 6349     00:15     22:45          76V       M38431           M38440
# 6370     00:15     23:00          76V       M38443           M38472
# 6393     00:25     22:50          76V       M38477           M38478
# 6397     00:25     22:50          76V       M38477           M38478
# 6658     04:30     23:25          76Y       W80925           W80926
# 6660     04:30     23:25          76Y       W80925           W80926
# 6661     04:30     23:25          76Y       W80925           W80926
#
#      Svc Type  Pax Week-Day
# 6027       FF  000  0000060
# 6031       FF  000  0000060
# 6033       FF  000  0000060
# 6052       FF  000  1000000
# 6349       FF  000  0004000
# 6370       FF  000  0000060
# 6393       FF  000  0000007
# 6397       FF  000  0000007
# 6658       HH  000  1234507
# 6660       HH  000  1234007
# 6661       HH  000  0000500

# %%
df_frame66 = df_orig.query('KeyX == 2  & Key == 67 & Kdept == 11 & Karvl == 10')
df_frame66['FlightNumberArvl'] = df_frame66['Arvl Sta']
df_frame66['FlightNumbeR'] = df_frame66['Dept Sta'].apply(lambda x: x[1:8])
df_frame66['Dept Sta'] = df_frame66['Arvl-Hora'].apply( lambda x: x[0:3])
df_frame66['Arvl Sta'] = df_frame66['Dept-Hora'].apply( lambda  x: x[5:8])
df_frame66['Arvl Day'] = df_frame66['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame66['Dept Day'] = df_frame66['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
df_frame66['Trilho'] = ''
df_frame66['Pax'] = df_frame66['Pax-Subfleet'].apply( lambda x: x[0:3])
df_frame66['Pax-Subfleet'] = df_frame66['Pax-Subfleet'].apply(lambda x: x[3:6])
df_frame66['Arvl-Hora'] = df_frame66['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10] )
df_frame66['Dept-Hora'] = df_frame66['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
df_frame66 = df_frame66[['Dept Sta', 'Arvl Sta', 'Dept Day', 'Arvl Day', 'Dept-Hora', 'Arvl-Hora','Pax-Subfleet','FlightNumbeR','FlightNumberArvl', 'Trilho','Svc Type', 'Pax', 'Week-Day']]
p39 = df_frame66
p39
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1556344796.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame66['FlightNumberArvl'] = df_frame66['Arvl Sta']
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1556344796.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame66['FlightNumbeR'] = df_frame66['Dept Sta'].apply(lambda x: x[1:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1556344796.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame66['Dept Sta'] = df_frame66['Arvl-Hora'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1556344796.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame66['Arvl Sta'] = df_frame66['Dept-Hora'].apply( lambda  x: x[5:8])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1556344796.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame66['Arvl Day'] = df_frame66['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1556344796.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame66['Dept Day'] = df_frame66['Dept Day'].apply(lambda x: x[0:2] + '/' + x[2:5] + '/' + '2023' + ' á ' + x[5:7] + '/' + x[7:10] + '/' + '2023')
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1556344796.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame66['Trilho'] = ''
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1556344796.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame66['Pax'] = df_frame66['Pax-Subfleet'].apply( lambda x: x[0:3])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1556344796.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame66['Pax-Subfleet'] = df_frame66['Pax-Subfleet'].apply(lambda x: x[3:6])
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1556344796.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame66['Arvl-Hora'] = df_frame66['Arvl-Hora'].apply( lambda x: x[6:8] + ':' + x[8:10] )
# C:\Users\gabri\AppData\Local\Temp\ipykernel_9332\1556344796.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_frame66['Dept-Hora'] = df_frame66['Dept-Hora'].apply( lambda x: x[0:2] + ':' + x[2:4])
#      Dept Sta Arvl Sta                   Dept Day                   Arvl Day  \
# 6230      FRA      REC  05/NOV/2023 á 18/MAR/2023  05/NOV/2023 á 18/MAR/2023
#
#      Dept-Hora Arvl-Hora Pax-Subfleet FlightNumbeR FlightNumberArvl Trilho  \
# 6230     00:20     22:20          77X      GEC8254          GEC8255
#
#      Svc Type  Pax Week-Day
# 6230       FF  000  0000060
